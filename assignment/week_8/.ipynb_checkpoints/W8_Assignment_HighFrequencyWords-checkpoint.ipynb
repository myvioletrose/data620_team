# %% [markdown]
# # Week 8: High Frequency Words
#
# ##### Jimmy Ng & Corey Arnouts
#
# Oct 16, 2020

# %% [markdown]
# ### Questions
# 1. Choose a corpus of interest.
#
# 2. How many total unique words are in the corpus? (Please feel free to define unique words in any interesting, defensible way).
#
# 3. Taking the most common words, how many unique words represent half of the total words in the corpus?
#
# 4. Identify the 200 highest frequency words in this corpus.
#
# 5. Create a graph that shows the relative frequency of these 200 words.
#
# 6. Does the observed relative frequency of these words follow Zipf’s law? Explain.
#
# 7. In what ways do you think the frequency of the words in this corpus differ from “all words in all corpora.”

# %% [markdown]
# https://www.youtube.com/watch?v=8Wy1CGeH0f4&feature=youtu.be&ab_channel=CoreyArnouts

# %% [markdown]
# ## 0. Set up

# %%
import nltk 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 1. Choose a corpus of interest.
#
# We decide to get free access from the Gutenberg library and work on the popular novel "Emma" by Jane Austen.

# %%
from nltk.corpus import gutenberg
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\arnou\AppData\Roaming\nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# True

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
emma = nltk.corpus.gutenberg.words('austen-emma.txt')

# %% [markdown]
# ## 2. How many total unique words are in the corpus?

# %% [markdown]
# ### total number of words

# %%
len(emma)
# Out:
# 192427

# %% [markdown]
# ### unique count of words that are alphabetic characters

# %%
len(set(w.lower() for w in emma if w.isalpha()))
# Out:
# 7079

# %% [markdown]
# ### let's explore a bit more by looking at frequency distribution of words by length

# %%
wAll = [len(w) for w in emma if w.isalpha()]
fdist_all = nltk.FreqDist(wAll)

{k: v for k, v in sorted(fdist_all.items(), reverse = False)}
# Out:
# {1: 7317,
#  2: 30785,
#  3: 37795,
#  4: 30650,
#  5: 16804,
#  6: 11593,
#  7: 9967,
#  8: 5856,
#  9: 5389,
#  10: 2742,
#  11: 1353,
#  12: 792,
#  13: 409,
#  14: 97,
#  15: 38,
#  16: 6,
#  17: 7}

# %%
fdist_all.plot()
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# The most used words have length of 3, 2 and 4.

# %% [markdown]
# ## 3. Taking the most common words, how many unique words represent half of the total words in the corpus?

# %%
wAll = [w for w in emma if w.isalpha()]
mostCommon = nltk.FreqDist(wAll)

print(mostCommon)
# Out:
# <FreqDist with 7535 samples and 161600 outcomes>

# %%
commonDf = pd.DataFrame(mostCommon.most_common(100))
print(commonDf.head(100))
# Out:
#           0     1
# 0        to  5183
# 1       the  4844
# 2       and  4672
# 3        of  4279
# 4         I  3178
# ..      ...   ...
# 95      who   281
# 96  herself   279
# 97      now   273
# 98     time   272
# 99      can   270
#
# [100 rows x 2 columns]

# %%
commonDf.columns = ['word', 'freq']
commonDf['cumulative_freq'] = np.cumsum(commonDf['freq'])
num = (commonDf['cumulative_freq'] >= (161600/2)).idxmax()

print(f'{num} of the most common words make up half of the total words in Emma.')
# Out:
# 65 of the most common words make up half of the total words in Emma.

# %% [markdown]
# ## 4. Identify the 200 highest frequency words in this corpus.

# %%
mostCommon.most_common(200)
# Out:
# [('to', 5183),
#  ('the', 4844),
#  ('and', 4672),
#  ('of', 4279),
#  ('I', 3178),
#  ('a', 3004),
#  ('was', 2385),
#  ('her', 2381),
#  ('it', 2128),
#  ('in', 2118),
#  ('not', 2101),
#  ('be', 1970),
#  ('she', 1778),
#  ('that', 1730),
#  ('you', 1677),
#  ('had', 1606),
#  ('as', 1387),
#  ('he', 1365),
#  ('for', 1321),
#  ('have', 1301),
#  ('is', 1220),
#  ('with', 1187),
#  ('Mr', 1153),
#  ('very', 1151),
#  ('but', 1148),
#  ('his', 1088),
#  ('at', 997),
#  ('s', 933),
#  ('so', 924),
#  ('Emma', 865),
#  ('all', 835),
#  ('could', 825),
#  ('would', 815),
#  ('been', 759),
#  ('him', 758),
#  ('Mrs', 699),
#  ('on', 677),
#  ('any', 651),
#  ('my', 619),
#  ('no', 616),
#  ('Miss', 592),
#  ('were', 591),
#  ('do', 580),
#  ('must', 564),
#  ('me', 564),
#  ('She', 562),
#  ('will', 559),
#  ('by', 558),
#  ('which', 552),
#  ('from', 535),
#  ('Harriet', 506),
#  ('or', 490),
#  ('said', 484),
#  ('much', 478),
#  ('more', 464),
#  ('an', 452),
#  ('are', 447),
# ...

# %% [markdown]
# ## 5. Create a graph that shows the relative frequency of these 200 words.

# %%
fig = plt.figure(figsize = (20, 15), dpi = 100, facecolor = 'w', edgecolor = 'k')
mostCommon.plot(200, cumulative = False)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# ## 5. Does the observed relative frequency of these words follow Zipf’s law? Explain.

# %% [markdown]
# It looks like the distribution of words generally follows Zipf's law with a few words being used many times and many words being used rarely. The rank frequency proportional of word frequency being equal to 1/rank does not exactly hold true for the most common words, as many of the top words are used a very similar amount of times.

# %% [markdown]
# ##  6.In what ways do you think the frequency of the words in this corpus differ from “all words in all corpora.

# %% [markdown]
# The top word on this distribution of words is the word 'to' which is usually the third most common word so it is interesting that 'to' outpaces words like 'the'. I also notices that the words 'she' and 'her' dramatically outpace the words 'he' and 'him' my guess is this is because the protagonist is a female lead and often the author is describing her thoughts and actions. This also why the word 'Emma' has so many uses as well because that is the name of the main protagonist. I also noticed that the word 'love' is in the top 100 most common words, I would wager that this is not usually the case in everyday language.
