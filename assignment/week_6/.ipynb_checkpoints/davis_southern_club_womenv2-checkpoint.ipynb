# %% [markdown]
# # Weeky 6 Assignment: Davis Southern Club Women
#
# ##### Jimmy Ng & Corey Arnouts
#
# Oct 3, 2020
#
# Here is a dataset that shows a simple 2-node network:  the attendance of 18 Southern Women at 14 social events

# %% [markdown]
# https://www.youtube.com/watch?v=afzbSe0g48Y&feature=youtu.be&ab_channel=CoreyArnouts

# %% [markdown]
# ## Import modules, data

# %%
import networkx as nx
import networkx.algorithms.bipartite as bipartite
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
G = nx.davis_southern_women_graph()

# %%
nx.bipartite.is_bipartite(G)
# Out:
# True

# %%
list(G.nodes(data = True))
# Out:
# [('Evelyn Jefferson', {'bipartite': 0}),
#  ('Laura Mandeville', {'bipartite': 0}),
#  ('Theresa Anderson', {'bipartite': 0}),
#  ('Brenda Rogers', {'bipartite': 0}),
#  ('Charlotte McDowd', {'bipartite': 0}),
#  ('Frances Anderson', {'bipartite': 0}),
#  ('Eleanor Nye', {'bipartite': 0}),
#  ('Pearl Oglethorpe', {'bipartite': 0}),
#  ('Ruth DeSand', {'bipartite': 0}),
#  ('Verne Sanderson', {'bipartite': 0}),
#  ('Myra Liddel', {'bipartite': 0}),
#  ('Katherina Rogers', {'bipartite': 0}),
#  ('Sylvia Avondale', {'bipartite': 0}),
#  ('Nora Fayette', {'bipartite': 0}),
#  ('Helen Lloyd', {'bipartite': 0}),
#  ('Dorothy Murchison', {'bipartite': 0}),
#  ('Olivia Carleton', {'bipartite': 0}),
#  ('Flora Price', {'bipartite': 0}),
#  ('E1', {'bipartite': 1}),
#  ('E2', {'bipartite': 1}),
#  ('E3', {'bipartite': 1}),
#  ('E4', {'bipartite': 1}),
#  ('E5', {'bipartite': 1}),
#  ('E6', {'bipartite': 1}),
#  ('E7', {'bipartite': 1}),
#  ('E8', {'bipartite': 1}),
#  ('E9', {'bipartite': 1}),
#  ('E10', {'bipartite': 1}),
#  ('E11', {'bipartite': 1}),
#  ('E12', {'bipartite': 1}),
#  ('E13', {'bipartite': 1}),
#  ('E14', {'bipartite': 1})]

# %%
list(G.edges(data = True))
# Out:
# [('Evelyn Jefferson', 'E1', {}),
#  ('Evelyn Jefferson', 'E2', {}),
#  ('Evelyn Jefferson', 'E3', {}),
#  ('Evelyn Jefferson', 'E4', {}),
#  ('Evelyn Jefferson', 'E5', {}),
#  ('Evelyn Jefferson', 'E6', {}),
#  ('Evelyn Jefferson', 'E8', {}),
#  ('Evelyn Jefferson', 'E9', {}),
#  ('Laura Mandeville', 'E1', {}),
#  ('Laura Mandeville', 'E2', {}),
#  ('Laura Mandeville', 'E3', {}),
#  ('Laura Mandeville', 'E5', {}),
#  ('Laura Mandeville', 'E6', {}),
#  ('Laura Mandeville', 'E7', {}),
#  ('Laura Mandeville', 'E8', {}),
#  ('Theresa Anderson', 'E2', {}),
#  ('Theresa Anderson', 'E3', {}),
#  ('Theresa Anderson', 'E4', {}),
#  ('Theresa Anderson', 'E5', {}),
#  ('Theresa Anderson', 'E6', {}),
#  ('Theresa Anderson', 'E7', {}),
#  ('Theresa Anderson', 'E8', {}),
#  ('Theresa Anderson', 'E9', {}),
#  ('Brenda Rogers', 'E1', {}),
#  ('Brenda Rogers', 'E3', {}),
#  ('Brenda Rogers', 'E4', {}),
#  ('Brenda Rogers', 'E5', {}),
#  ('Brenda Rogers', 'E6', {}),
#  ('Brenda Rogers', 'E7', {}),
#  ('Brenda Rogers', 'E8', {}),
#  ('Charlotte McDowd', 'E3', {}),
#  ('Charlotte McDowd', 'E4', {}),
#  ('Charlotte McDowd', 'E5', {}),
#  ('Charlotte McDowd', 'E7', {}),
#  ('Frances Anderson', 'E3', {}),
#  ('Frances Anderson', 'E5', {}),
#  ('Frances Anderson', 'E6', {}),
#  ('Frances Anderson', 'E8', {}),
#  ('Eleanor Nye', 'E5', {}),
#  ('Eleanor Nye', 'E6', {}),
#  ('Eleanor Nye', 'E7', {}),
#  ('Eleanor Nye', 'E8', {}),
#  ('Pearl Oglethorpe', 'E6', {}),
#  ('Pearl Oglethorpe', 'E8', {}),
#  ('Pearl Oglethorpe', 'E9', {}),
#  ('Ruth DeSand', 'E5', {}),
#  ('Ruth DeSand', 'E7', {}),
#  ('Ruth DeSand', 'E8', {}),
#  ('Ruth DeSand', 'E9', {}),
#  ('Verne Sanderson', 'E7', {}),
#  ('Verne Sanderson', 'E8', {}),
#  ('Verne Sanderson', 'E9', {}),
#  ('Verne Sanderson', 'E12', {}),
#  ('Myra Liddel', 'E8', {}),
#  ('Myra Liddel', 'E9', {}),
#  ('Myra Liddel', 'E10', {}),
#  ('Myra Liddel', 'E12', {}),
#  ('Katherina Rogers', 'E8', {}),
#  ('Katherina Rogers', 'E9', {}),
#  ('Katherina Rogers', 'E10', {}),
#  ('Katherina Rogers', 'E12', {}),
#  ('Katherina Rogers', 'E13', {}),
#  ('Katherina Rogers', 'E14', {}),
#  ('Sylvia Avondale', 'E7', {}),
#  ('Sylvia Avondale', 'E8', {}),
#  ('Sylvia Avondale', 'E9', {}),
#  ('Sylvia Avondale', 'E10', {}),
#  ('Sylvia Avondale', 'E12', {}),
#  ('Sylvia Avondale', 'E13', {}),
#  ('Sylvia Avondale', 'E14', {}),
#  ('Nora Fayette', 'E6', {}),
#  ('Nora Fayette', 'E7', {}),
#  ('Nora Fayette', 'E9', {}),
#  ('Nora Fayette', 'E10', {}),
#  ('Nora Fayette', 'E11', {}),
#  ('Nora Fayette', 'E12', {}),
#  ('Nora Fayette', 'E13', {}),
#  ('Nora Fayette', 'E14', {}),
#  ('Helen Lloyd', 'E7', {}),
#  ('Helen Lloyd', 'E8', {}),
#  ('Helen Lloyd', 'E10', {}),
#  ('Helen Lloyd', 'E11', {}),
#  ('Helen Lloyd', 'E12', {}),
#  ('Dorothy Murchison', 'E8', {}),
#  ('Dorothy Murchison', 'E9', {}),
#  ('Olivia Carleton', 'E9', {}),
#  ('Olivia Carleton', 'E11', {}),
#  ('Flora Price', 'E9', {}),
#  ('Flora Price', 'E11', {})]

# %%
women_nodes = [node for node in G.nodes() if G.node[node]['bipartite'] == 0]
event_nodes = [node for node in G.nodes() if G.node[node]['bipartite'] == 1]

# %%
print('there are {x} women in this data set'.format(x = len(women_nodes)))
print('there are {x} clubs/events in this data set'.format(x = len(event_nodes)))
# Out:
# there are 18 women in this data set
# there are 14 clubs/events in this data set

# %%
women_nodes
# Out:
# ['Evelyn Jefferson',
#  'Laura Mandeville',
#  'Theresa Anderson',
#  'Brenda Rogers',
#  'Charlotte McDowd',
#  'Frances Anderson',
#  'Eleanor Nye',
#  'Pearl Oglethorpe',
#  'Ruth DeSand',
#  'Verne Sanderson',
#  'Myra Liddel',
#  'Katherina Rogers',
#  'Sylvia Avondale',
#  'Nora Fayette',
#  'Helen Lloyd',
#  'Dorothy Murchison',
#  'Olivia Carleton',
#  'Flora Price']

# %%
event_nodes
# Out:
# ['E1',
#  'E2',
#  'E3',
#  'E4',
#  'E5',
#  'E6',
#  'E7',
#  'E8',
#  'E9',
#  'E10',
#  'E11',
#  'E12',
#  'E13',
#  'E14']

# %% [markdown]
# ## Draw bipartite graph

# %%
fig = plt.figure(figsize = (18, 10), dpi = 100, facecolor = 'w', edgecolor = 'k')

# set positions, layout for all nodes
pos = nx.fruchterman_reingold_layout(G) 

# get the node name as the key and the label as its value 

color_map = []
d = dict(G.degree)

women_labels = {}    
for node in G.nodes():
    if node in women_nodes:        
        women_labels[node] = node
        color_map.append('red')            
        
event_labels = {}    
for node in G.nodes():
    if node in event_nodes:      
        event_labels[node] = node
        color_map.append('lime')

# draw graph with no label
nx.draw(G, pos, with_labels = False, node_color = color_map,node_size=[v * 100 for v in d.values()])

# draw nodes, change font size, color
nx.draw_networkx_labels(G, 
                        pos, 
                        nodelist = women_nodes, 
                        labels = women_labels,                          
                        font_size = 16,
                        font_color = "black")

nx.draw_networkx_labels(G,
                        pos,
                        nodelist = event_nodes,
                        labels = event_labels,                        
                        font_size = 24,
                        font_color = "black")

weights = [edata['weight'] for f,t,edata in W.edges(data=True)]

# edges
nx.draw_networkx_edges(G, pos, width = weights, alpha = 0.5)

# %% [markdown]
# ## Centrality measure

# %%
women_nodes_with_centrality = [node for node in nx.bipartite.degree_centrality(G, women_nodes).items() if len(node[0]) >=10]

pd.Series(data = dict(women_nodes_with_centrality)).sort_values(ascending = False)
# Out:
# Theresa Anderson     0.571429
# Nora Fayette         0.571429
# Evelyn Jefferson     0.571429
# Brenda Rogers        0.500000
# Laura Mandeville     0.500000
# Sylvia Avondale      0.500000
# Katherina Rogers     0.428571
# Helen Lloyd          0.357143
# Myra Liddel          0.285714
# Charlotte McDowd     0.285714
# Verne Sanderson      0.285714
# Frances Anderson     0.285714
# Ruth DeSand          0.285714
# Eleanor Nye          0.285714
# Pearl Oglethorpe     0.214286
# Flora Price          0.142857
# Dorothy Murchison    0.142857
# Olivia Carleton      0.142857
# dtype: float64

# %%
event_nodes_with_centrality = [node for node in nx.bipartite.degree_centrality(G, event_nodes).items() if len(node[0]) <=3]

pd.Series(data = dict(event_nodes_with_centrality)).sort_values(ascending = False)
# Out:
# E8     0.777778
# E9     0.666667
# E7     0.555556
# E6     0.444444
# E5     0.444444
# E12    0.333333
# E3     0.333333
# E10    0.277778
# E4     0.222222
# E11    0.222222
# E13    0.166667
# E2     0.166667
# E1     0.166667
# E14    0.166667
# dtype: float64

# %% [markdown]
# Take a quick look from above measures, it seems that Evelyn Jefferson, Nora Fayette, Theresa Anderson are the most sociable people and events 7, 8 and 9 seem the most important as they connect most people/attendees.

# %% [markdown]
# ## Create a summary df
#
# Caution when reading below summary table, it is a mix of women and events, i.e. that's a many-to-many relationship. For example, Evelyn Jefferson has the degree centrality of 0.571429, and she attended 8 separate events. One of them is E8 which has the degree centrality of 0.777778 and 14 attendees.

# %%
women_centralility = pd.Series(data = dict(women_nodes_with_centrality)).sort_values(ascending = False).to_frame()
women_centralility.reset_index(inplace = True)
women_centralility.columns = ['women', 'women_degree_centrality']

event_centralility = pd.Series(data = dict(event_nodes_with_centrality)).sort_values(ascending = False).to_frame()
event_centralility.reset_index(inplace = True)
event_centralility.columns = ['event', 'event_degree_centrality']

df = pd.DataFrame(list(G.edges(data = True)), columns = ['women', 'event', 'attribute'])\
.drop(columns = ['attribute'])\
.merge(women_centralility, on = "women")\
.merge(event_centralility, on = "event")

w = pd.DataFrame({'event_attended' : df.groupby("women").size()})
e = pd.DataFrame({'event_attendees' : df.groupby("event").size()})

df = df\
.merge(w, on = "women")\
.merge(e, on = "event")

# %%
pd.set_option('display.max_rows', df.shape[0]+1)
df = df.sort_values(by = ["women_degree_centrality", "women", "event_degree_centrality"], ascending = [False, True, False])\
.reset_index(drop = True)
df
# Out:
#                 women event  women_degree_centrality  event_degree_centrality  \
# 0    Evelyn Jefferson    E8                 0.571429                 0.777778
# 1    Evelyn Jefferson    E9                 0.571429                 0.666667
# 2    Evelyn Jefferson    E5                 0.571429                 0.444444
# 3    Evelyn Jefferson    E6                 0.571429                 0.444444
# 4    Evelyn Jefferson    E3                 0.571429                 0.333333
# 5    Evelyn Jefferson    E4                 0.571429                 0.222222
# 6    Evelyn Jefferson    E1                 0.571429                 0.166667
# 7    Evelyn Jefferson    E2                 0.571429                 0.166667
# 8        Nora Fayette    E9                 0.571429                 0.666667
# 9        Nora Fayette    E7                 0.571429                 0.555556
# 10       Nora Fayette    E6                 0.571429                 0.444444
# 11       Nora Fayette   E12                 0.571429                 0.333333
# 12       Nora Fayette   E10                 0.571429                 0.277778
# 13       Nora Fayette   E11                 0.571429                 0.222222
# 14       Nora Fayette   E13                 0.571429                 0.166667
# 15       Nora Fayette   E14                 0.571429                 0.166667
# 16   Theresa Anderson    E8                 0.571429                 0.777778
# 17   Theresa Anderson    E9                 0.571429                 0.666667
# 18   Theresa Anderson    E7                 0.571429                 0.555556
# 19   Theresa Anderson    E5                 0.571429                 0.444444
# 20   Theresa Anderson    E6                 0.571429                 0.444444
# 21   Theresa Anderson    E3                 0.571429                 0.333333
# 22   Theresa Anderson    E4                 0.571429                 0.222222
# 23   Theresa Anderson    E2                 0.571429                 0.166667
# 24      Brenda Rogers    E8                 0.500000                 0.777778
# 25      Brenda Rogers    E7                 0.500000                 0.555556
# 26      Brenda Rogers    E5                 0.500000                 0.444444
# 27      Brenda Rogers    E6                 0.500000                 0.444444
# 28      Brenda Rogers    E3                 0.500000                 0.333333
# 29      Brenda Rogers    E4                 0.500000                 0.222222
# 30      Brenda Rogers    E1                 0.500000                 0.166667
# 31   Laura Mandeville    E8                 0.500000                 0.777778
# 32   Laura Mandeville    E7                 0.500000                 0.555556
# 33   Laura Mandeville    E5                 0.500000                 0.444444
# 34   Laura Mandeville    E6                 0.500000                 0.444444
# 35   Laura Mandeville    E3                 0.500000                 0.333333
# 36   Laura Mandeville    E1                 0.500000                 0.166667
# 37   Laura Mandeville    E2                 0.500000                 0.166667
# 38    Sylvia Avondale    E8                 0.500000                 0.777778
# 39    Sylvia Avondale    E9                 0.500000                 0.666667
# 40    Sylvia Avondale    E7                 0.500000                 0.555556
# 41    Sylvia Avondale   E12                 0.500000                 0.333333
# 42    Sylvia Avondale   E10                 0.500000                 0.277778
# 43    Sylvia Avondale   E13                 0.500000                 0.166667
# 44    Sylvia Avondale   E14                 0.500000                 0.166667
# 45   Katherina Rogers    E8                 0.428571                 0.777778
# 46   Katherina Rogers    E9                 0.428571                 0.666667
# 47   Katherina Rogers   E12                 0.428571                 0.333333
# 48   Katherina Rogers   E10                 0.428571                 0.277778
# 49   Katherina Rogers   E13                 0.428571                 0.166667
# 50   Katherina Rogers   E14                 0.428571                 0.166667
# 51        Helen Lloyd    E8                 0.357143                 0.777778
# 52        Helen Lloyd    E7                 0.357143                 0.555556
# 53        Helen Lloyd   E12                 0.357143                 0.333333
# 54        Helen Lloyd   E10                 0.357143                 0.277778
# 55        Helen Lloyd   E11                 0.357143                 0.222222
# 56   Charlotte McDowd    E7                 0.285714                 0.555556
# 57   Charlotte McDowd    E5                 0.285714                 0.444444
# 58   Charlotte McDowd    E3                 0.285714                 0.333333
# 59   Charlotte McDowd    E4                 0.285714                 0.222222
# 60        Eleanor Nye    E8                 0.285714                 0.777778
# 61        Eleanor Nye    E7                 0.285714                 0.555556
# 62        Eleanor Nye    E5                 0.285714                 0.444444
# 63        Eleanor Nye    E6                 0.285714                 0.444444
# 64   Frances Anderson    E8                 0.285714                 0.777778
# 65   Frances Anderson    E5                 0.285714                 0.444444
# 66   Frances Anderson    E6                 0.285714                 0.444444
# 67   Frances Anderson    E3                 0.285714                 0.333333
# 68        Myra Liddel    E8                 0.285714                 0.777778
# 69        Myra Liddel    E9                 0.285714                 0.666667
# 70        Myra Liddel   E12                 0.285714                 0.333333
# 71        Myra Liddel   E10                 0.285714                 0.277778
# 72        Ruth DeSand    E8                 0.285714                 0.777778
# 73        Ruth DeSand    E9                 0.285714                 0.666667
# 74        Ruth DeSand    E7                 0.285714                 0.555556
# 75        Ruth DeSand    E5                 0.285714                 0.444444
# 76    Verne Sanderson    E8                 0.285714                 0.777778
# 77    Verne Sanderson    E9                 0.285714                 0.666667
# 78    Verne Sanderson    E7                 0.285714                 0.555556
# 79    Verne Sanderson   E12                 0.285714                 0.333333
# 80   Pearl Oglethorpe    E8                 0.214286                 0.777778
# 81   Pearl Oglethorpe    E9                 0.214286                 0.666667
# 82   Pearl Oglethorpe    E6                 0.214286                 0.444444
# 83  Dorothy Murchison    E8                 0.142857                 0.777778
# 84  Dorothy Murchison    E9                 0.142857                 0.666667
# 85        Flora Price    E9                 0.142857                 0.666667
# 86        Flora Price   E11                 0.142857                 0.222222
# 87    Olivia Carleton    E9                 0.142857                 0.666667
# 88    Olivia Carleton   E11                 0.142857                 0.222222
#
#     event_attended  event_attendees
# 0                8               14
# 1                8               12
# 2                8                8
# 3                8                8
# 4                8                6
# 5                8                4
# 6                8                3
# 7                8                3
# 8                8               12
# 9                8               10
# 10               8                8
# 11               8                6
# 12               8                5
# 13               8                4
# 14               8                3
# 15               8                3
# 16               8               14
# 17               8               12
# 18               8               10
# 19               8                8
# 20               8                8
# 21               8                6
# 22               8                4
# 23               8                3
# 24               7               14
# 25               7               10
# 26               7                8
# 27               7                8
# 28               7                6
# 29               7                4
# 30               7                3
# 31               7               14
# 32               7               10
# 33               7                8
# 34               7                8
# 35               7                6
# 36               7                3
# 37               7                3
# 38               7               14
# 39               7               12
# 40               7               10
# 41               7                6
# 42               7                5
# 43               7                3
# 44               7                3
# 45               6               14
# 46               6               12
# 47               6                6
# 48               6                5
# 49               6                3
# 50               6                3
# 51               5               14
# 52               5               10
# 53               5                6
# 54               5                5
# 55               5                4
# 56               4               10
# 57               4                8
# 58               4                6
# 59               4                4
# 60               4               14
# 61               4               10
# 62               4                8
# 63               4                8
# 64               4               14
# 65               4                8
# 66               4                8
# 67               4                6
# 68               4               14
# 69               4               12
# 70               4                6
# 71               4                5
# 72               4               14
# 73               4               12
# 74               4               10
# 75               4                8
# 76               4               14
# 77               4               12
# 78               4               10
# 79               4                6
# 80               3               14
# 81               3               12
# 82               3                8
# 83               2               14
# 84               2               12
# 85               2               12
# 86               2                4
# 87               2               12
# 88               2                4

# %% [markdown]
# ## Projections on "Women" (as primary set of nodes)
#
# Let's use "women" as a primary set and do projections on it.

# %%
women_graph = nx.bipartite.projection.projected_graph(G, women_nodes)

for n, d in women_graph.nodes(data = True):
    women_graph.node[n]['neighbors_count'] = len(list(women_graph.neighbors(n)))

list(women_graph.node(data=True))
# Out:
# [('Evelyn Jefferson', {'bipartite': 0, 'neighbors_count': 17}),
#  ('Laura Mandeville', {'bipartite': 0, 'neighbors_count': 15}),
#  ('Theresa Anderson', {'bipartite': 0, 'neighbors_count': 17}),
#  ('Brenda Rogers', {'bipartite': 0, 'neighbors_count': 15}),
#  ('Charlotte McDowd', {'bipartite': 0, 'neighbors_count': 11}),
#  ('Frances Anderson', {'bipartite': 0, 'neighbors_count': 15}),
#  ('Eleanor Nye', {'bipartite': 0, 'neighbors_count': 15}),
#  ('Pearl Oglethorpe', {'bipartite': 0, 'neighbors_count': 16}),
#  ('Ruth DeSand', {'bipartite': 0, 'neighbors_count': 17}),
#  ('Verne Sanderson', {'bipartite': 0, 'neighbors_count': 17}),
#  ('Myra Liddel', {'bipartite': 0, 'neighbors_count': 16}),
#  ('Katherina Rogers', {'bipartite': 0, 'neighbors_count': 16}),
#  ('Sylvia Avondale', {'bipartite': 0, 'neighbors_count': 17}),
#  ('Nora Fayette', {'bipartite': 0, 'neighbors_count': 17}),
#  ('Helen Lloyd', {'bipartite': 0, 'neighbors_count': 17}),
#  ('Dorothy Murchison', {'bipartite': 0, 'neighbors_count': 16}),
#  ('Olivia Carleton', {'bipartite': 0, 'neighbors_count': 12}),
#  ('Flora Price', {'bipartite': 0, 'neighbors_count': 12})]

# %%
fig = plt.figure(figsize = (18, 10), dpi = 100, facecolor = 'w', edgecolor = 'k')
nx.draw(women_graph, 
        node_color = "lime",
        font_size = 12,
        node_order = 'neighbors_count', 
        layout = 'spring',
        with_labels = True)

# %% [markdown]
# Above graph is a bit hard to read, it seems many of them are interconnected to each other (as most have large number of neighbors). What would happen if we break the graph by removing the three women?

# %%
women_graph.remove_nodes_from(["Evelyn Jefferson", "Nora Fayette", "Theresa Anderson"])
list(women_graph.node(data = True))
# Out:
# [('Laura Mandeville', {'bipartite': 0, 'neighbors_count': 15}),
#  ('Brenda Rogers', {'bipartite': 0, 'neighbors_count': 15}),
#  ('Charlotte McDowd', {'bipartite': 0, 'neighbors_count': 11}),
#  ('Frances Anderson', {'bipartite': 0, 'neighbors_count': 15}),
#  ('Eleanor Nye', {'bipartite': 0, 'neighbors_count': 15}),
#  ('Pearl Oglethorpe', {'bipartite': 0, 'neighbors_count': 16}),
#  ('Ruth DeSand', {'bipartite': 0, 'neighbors_count': 17}),
#  ('Verne Sanderson', {'bipartite': 0, 'neighbors_count': 17}),
#  ('Myra Liddel', {'bipartite': 0, 'neighbors_count': 16}),
#  ('Katherina Rogers', {'bipartite': 0, 'neighbors_count': 16}),
#  ('Sylvia Avondale', {'bipartite': 0, 'neighbors_count': 17}),
#  ('Helen Lloyd', {'bipartite': 0, 'neighbors_count': 17}),
#  ('Dorothy Murchison', {'bipartite': 0, 'neighbors_count': 16}),
#  ('Olivia Carleton', {'bipartite': 0, 'neighbors_count': 12}),
#  ('Flora Price', {'bipartite': 0, 'neighbors_count': 12})]

# %%
fig = plt.figure(figsize = (18, 10), dpi = 100, facecolor = 'w', edgecolor = 'k')
nx.draw(women_graph, 
        node_color = "pink",
        font_size = 12,
        node_order = 'neighbors_count', 
        layout = 'random',
        with_labels = True)

# %% [markdown]
# ## Projections on "Events" (as primary set of nodes)
#
# Let's look at events as primary set.

# %%
event_graph = nx.bipartite.projection.projected_graph(G, event_nodes)

for n, d in event_graph.nodes(data = True):
    event_graph.node[n]['neighbors_count'] = len(list(event_graph.neighbors(n)))

list(event_graph.node(data=True))
# Out:
# [('E1', {'bipartite': 1, 'neighbors_count': 8}),
#  ('E2', {'bipartite': 1, 'neighbors_count': 8}),
#  ('E3', {'bipartite': 1, 'neighbors_count': 8}),
#  ('E4', {'bipartite': 1, 'neighbors_count': 8}),
#  ('E5', {'bipartite': 1, 'neighbors_count': 8}),
#  ('E6', {'bipartite': 1, 'neighbors_count': 13}),
#  ('E7', {'bipartite': 1, 'neighbors_count': 13}),
#  ('E8', {'bipartite': 1, 'neighbors_count': 13}),
#  ('E9', {'bipartite': 1, 'neighbors_count': 13}),
#  ('E10', {'bipartite': 1, 'neighbors_count': 8}),
#  ('E11', {'bipartite': 1, 'neighbors_count': 8}),
#  ('E12', {'bipartite': 1, 'neighbors_count': 8}),
#  ('E13', {'bipartite': 1, 'neighbors_count': 8}),
#  ('E14', {'bipartite': 1, 'neighbors_count': 8})]

# %%
fig = plt.figure(figsize = (18, 10), dpi = 100, facecolor = 'w', edgecolor = 'k')
nx.draw(event_graph, 
        node_color = 'lime',
        font_size = 18,
        font_color = 'red',
        node_order = 'neighbors_count', 
        layout = 'spring',
        with_labels = True)

# %% [markdown]
# Clearly, events 6, 7, 8 and 9 are the centers of all events. What would happen if we remove them from the graph?

# %%
event_graph.remove_nodes_from(["E6", "E7", "E8", "E9"])
list(event_graph.node(data=True))
# Out:
# [('E1', {'bipartite': 1, 'neighbors_count': 8}),
#  ('E2', {'bipartite': 1, 'neighbors_count': 8}),
#  ('E3', {'bipartite': 1, 'neighbors_count': 8}),
#  ('E4', {'bipartite': 1, 'neighbors_count': 8}),
#  ('E5', {'bipartite': 1, 'neighbors_count': 8}),
#  ('E10', {'bipartite': 1, 'neighbors_count': 8}),
#  ('E11', {'bipartite': 1, 'neighbors_count': 8}),
#  ('E12', {'bipartite': 1, 'neighbors_count': 8}),
#  ('E13', {'bipartite': 1, 'neighbors_count': 8}),
#  ('E14', {'bipartite': 1, 'neighbors_count': 8})]

# %%
nx.draw(event_graph, 
        node_color = "lime",
        node_order = 'neighbors_count', 
        layout = 'random',
        with_labels = True)

# %%
keyEvents = ["E6", "E7", "E8", "E9"]
df[df.event.isin(keyEvents)][['event', 'event_degree_centrality', 'event_attendees']]\
.sort_values(by = ["event_degree_centrality"], ascending = False)\
.drop_duplicates()\
.reset_index(drop = True)
# Out:
#   event  event_degree_centrality  event_attendees
# 0    E8                 0.777778               14
# 1    E9                 0.666667               12
# 2    E7                 0.555556               10
# 3    E6                 0.444444                8

# %% [markdown]
# ### Women Nodes if we Remove Events 6,7,8,9 (the events with high bridgeness)

# %%
G2 = nx.davis_southern_women_graph()

G2.remove_nodes_from(["E6", "E7", "E8", "E9"])


women_graph2 = nx.bipartite.projection.projected_graph(G2, women_nodes)

fig = plt.figure(figsize = (18, 10), dpi = 100, facecolor = 'w', edgecolor = 'k')
nx.draw(women_graph2, 
        node_color = "pink",
        font_size = 12,
        node_order = 'neighbors_count', 
        layout = 'random',
        with_labels = True)

# %% [markdown]
# ## Cliques

# %%
women_graph = nx.bipartite.projection.projected_graph(G, women_nodes)
    
women_cliques = list(nx.find_cliques(women_graph))

print('there are {x} cliques based on women in this network'.format(x = len(women_cliques)))

women_cliques
# Out:
# there are 3 cliques based on women in this network
# [['Theresa Anderson',
#   'Ruth DeSand',
#   'Evelyn Jefferson',
#   'Verne Sanderson',
#   'Sylvia Avondale',
#   'Nora Fayette',
#   'Helen Lloyd',
#   'Charlotte McDowd',
#   'Eleanor Nye',
#   'Frances Anderson',
#   'Brenda Rogers',
#   'Laura Mandeville'],
#  ['Theresa Anderson',
#   'Ruth DeSand',
#   'Evelyn Jefferson',
#   'Verne Sanderson',
#   'Sylvia Avondale',
#   'Nora Fayette',
#   'Helen Lloyd',
#   'Dorothy Murchison',
#   'Katherina Rogers',
#   'Myra Liddel',
#   'Pearl Oglethorpe',
#   'Flora Price',
#   'Olivia Carleton'],
#  ['Theresa Anderson',
#   'Ruth DeSand',
#   'Evelyn Jefferson',
#   'Verne Sanderson',
#   'Sylvia Avondale',
#   'Nora Fayette',
#   'Helen Lloyd',
#   'Dorothy Murchison',
#   'Katherina Rogers',
#   'Myra Liddel',
#   'Pearl Oglethorpe',
#   'Laura Mandeville',
#   'Eleanor Nye',
#   'Frances Anderson',
#   'Brenda Rogers']]

# %%
fig = plt.figure(figsize = (18, 10), dpi = 100, facecolor = 'w', edgecolor = 'k')
women_graph_projected = nx.bipartite.projection.projected_graph(G, women_nodes)

plt.subplot(131)
nx.draw(women_graph_projected.subgraph(women_cliques[0]), with_labels = True, node_color = "gold", font_color = "red")

plt.subplot(132)
nx.draw(women_graph_projected.subgraph(women_cliques[1]), with_labels = True, node_color = "blue", font_color = "red")

plt.subplot(133)
nx.draw(women_graph_projected.subgraph(women_cliques[2]), with_labels = True, node_color = "grey", font_color = "red")

# %%
event_graph = nx.bipartite.projection.projected_graph(G, event_nodes)
    
event_cliques = list(nx.find_cliques(event_graph))

print('there are {x} cliques based on events in this network'.format(x = len(event_cliques)))

event_cliques
# Out:
# there are 2 cliques based on events in this network
# [['E9', 'E6', 'E7', 'E8', 'E14', 'E13', 'E10', 'E11', 'E12'],
#  ['E9', 'E6', 'E7', 'E8', 'E5', 'E1', 'E2', 'E3', 'E4']]

# %%
fig = plt.figure(figsize = (18, 10), dpi = 100, facecolor = 'w', edgecolor = 'k')
event_graph_projected = nx.bipartite.projection.projected_graph(G, event_nodes)

plt.subplot(121)
nx.draw(event_graph_projected.subgraph(event_cliques[0]), with_labels = True, node_color = "lime", font_color = "black")

plt.subplot(122)
nx.draw(event_graph_projected.subgraph(event_cliques[1]), with_labels = True, node_color = "yellow", font_color = "black")
