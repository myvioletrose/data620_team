# %% [markdown]
# # Project 3 - Name Classification
#
# Jimmy Ng & Corey Arnouts
#
# Oct 23, 2020

# %% [markdown]
# ## Set up

# %%
import nltk
nltk.download('names')
from nltk.corpus import names
import random
# Out:
# [nltk_data] Downloading package names to
# [nltk_data]     C:\Users\arnou\AppData\Roaming\nltk_data...
# [nltk_data]   Package names is already up-to-date!

# %% [markdown]
# ## Data prep

# %% [markdown]
# ### Get name

# %%
names = ([(name, "male") for name in names.words("male.txt")] + \
         [(name, "female") for name in names.words("female.txt")])

# %%
random.seed(1234)
random.shuffle(names)

# %%
print('There are ' + str(len([g for (n, g) in names if g == 'female'])) + ' female names.')
print('There are ' + str(len([g for (n, g) in names if g == 'male'])) + ' male names.')
# Out:
# There are 5001 female names.
# There are 2943 male names.

# %% [markdown]
# ### Split data set into three

# %%
test, dev_test, training = names[:500], names[500:1000], names[1000:]

# %%
print('There are ' + str(len([g for (n, g) in training if g == 'female'])) + ' female names in the train set.')
print('There are ' + str(len([g for (n, g) in training if g == 'male'])) + ' male names in the train set.')
print("\n")
print('There are ' + str(len([g for (n, g) in dev_test if g == 'female'])) + ' female names in the dev test.')
print('There are ' + str(len([g for (n, g) in dev_test if g == 'male'])) + ' male names in the dev test.')
print("\n")
print('There are ' + str(len([g for (n, g) in test if g == 'female'])) + ' female names in the test set.')
print('There are ' + str(len([g for (n, g) in test if g == 'male'])) + ' male names in the test set.')
# Out:
# There are 4382 female names in the train set.
# There are 2562 male names in the train set.
#
#
# There are 319 female names in the dev test.
# There are 181 male names in the dev test.
#
#
# There are 300 female names in the test set.
# There are 200 male names in the test set.

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Error analysis
#
# Here's a function modified from the example in the textbook. We can use it to print out the error/discrepancy of our prediction and true label.

# %%
def error_analysis(FEATURES):        
    errors = [] 
    for (name, tag) in dev_test:
        guess = classifier.classify(FEATURES(name))
        if guess != tag:
            errors.append((tag, guess, name))
    print("Number of Errors: ", len(errors))    
    for (tag, guess, name) in sorted(errors):
        print('correct = {:<8} guess = {:<8s} name = {:<30}'.format(tag, guess, name))

# %% [markdown]
# ### Gender Feature 1
# Here's a function from the textbook. We can use it to serve as a benchmark for improvement.

# %%
def features1(name):
    features = {}
    features["first_letter"] = name[0].lower()
    features["last_letter"] = name[-1].lower()
    for letter in "abcdefghijklmnopqrstuvwxyz":
        features["count({})".format(letter)] = name.lower().count(letter)
        features["has({})".format(letter)] = (letter in name.lower())
    return features

# %%
train_set = [(features1(n), gender) for (n, gender) in training]
classifier = nltk.NaiveBayesClassifier.train(train_set)

devtest_set = [(features1(n), gender) for (n, gender) in dev_test]
print(nltk.classify.accuracy(classifier, devtest_set))
# Out:
# 0.758

# %%
error_analysis(features1)
# Out:
# Number of Errors:  121
# correct = female   guess = male     name = Ardyth
# correct = female   guess = male     name = Audry
# correct = female   guess = male     name = Bird
# correct = female   guess = male     name = Bridget
# correct = female   guess = male     name = Brooke
# correct = female   guess = male     name = Brynn
# correct = female   guess = male     name = Charis
# correct = female   guess = male     name = Chery
# correct = female   guess = male     name = Christin
# correct = female   guess = male     name = Corry
# correct = female   guess = male     name = Darb
# correct = female   guess = male     name = Dorolice
# correct = female   guess = male     name = Fawne
# correct = female   guess = male     name = Gennifer
# correct = female   guess = male     name = Gretchen
# correct = female   guess = male     name = Guenevere
# correct = female   guess = male     name = Heath
# correct = female   guess = male     name = Ingaberg
# correct = female   guess = male     name = Ingrid
# correct = female   guess = male     name = Justin
# correct = female   guess = male     name = Kaster
# correct = female   guess = male     name = Kim
# correct = female   guess = male     name = Kore
# correct = female   guess = male     name = Leanor
# correct = female   guess = male     name = Mag
# correct = female   guess = male     name = Mair
# correct = female   guess = male     name = Marget
# correct = female   guess = male     name = Margret
# correct = female   guess = male     name = Marys
# correct = female   guess = male     name = Mikako
# correct = female   guess = male     name = Modesty
# correct = female   guess = male     name = Myrah
# correct = female   guess = male     name = Nert
# correct = female   guess = male     name = Olly
# correct = female   guess = male     name = Pearl
# correct = female   guess = male     name = Pen
# correct = female   guess = male     name = Persis
# correct = female   guess = male     name = Pet
# correct = female   guess = male     name = Rhiamon
# correct = female   guess = male     name = Rhodie
# correct = female   guess = male     name = Rivkah
# correct = female   guess = male     name = Roby
# correct = female   guess = male     name = Ros
# correct = female   guess = male     name = Rosaleen
# correct = female   guess = male     name = Rosalynd
# correct = female   guess = male     name = Rosamond
# correct = female   guess = male     name = Rosie
# correct = female   guess = male     name = Shawn
# correct = female   guess = male     name = Sinead
# correct = female   guess = male     name = Tatum
# correct = female   guess = male     name = Thomasin
# correct = female   guess = male     name = Tobi
# correct = female   guess = male     name = Tomi
# correct = female   guess = male     name = Tommy
# correct = female   guess = male     name = Tony
# correct = female   guess = male     name = Trixy
# correct = female   guess = male     name = Winne
# correct = female   guess = male     name = Wynny
# correct = female   guess = male     name = Yehudit
# correct = male     guess = female   name = Adrian
# correct = male     guess = female   name = Alaa
# correct = male     guess = female   name = Alan
# correct = male     guess = female   name = Aldrich
# correct = male     guess = female   name = Alister
# correct = male     guess = female   name = Allah
# correct = male     guess = female   name = Andre
# correct = male     guess = female   name = Archie
# correct = male     guess = female   name = Barnabe
# correct = male     guess = female   name = Barrie
# correct = male     guess = female   name = Benji
# correct = male     guess = female   name = Bennett
# correct = male     guess = female   name = Constantine
# correct = male     guess = female   name = Devin
# correct = male     guess = female   name = Dmitri
# correct = male     guess = female   name = Earl
# correct = male     guess = female   name = Eddie
# correct = male     guess = female   name = Ely
# correct = male     guess = female   name = Emmery
# correct = male     guess = female   name = Ervin
# correct = male     guess = female   name = Frankie
# correct = male     guess = female   name = Graehme
# correct = male     guess = female   name = Granville
# correct = male     guess = female   name = Hamlin
# correct = male     guess = female   name = Hymie
# correct = male     guess = female   name = Ian
# correct = male     guess = female   name = Iggie
# correct = male     guess = female   name = Ivan
# correct = male     guess = female   name = Jedediah
# correct = male     guess = female   name = Jeffie
# correct = male     guess = female   name = Juan
# correct = male     guess = female   name = Juanita
# correct = male     guess = female   name = Kaiser
# correct = male     guess = female   name = Kenyon
# correct = male     guess = female   name = Lawrence
# correct = male     guess = female   name = Lefty
# correct = male     guess = female   name = Maurie
# correct = male     guess = female   name = Maximilien
# correct = male     guess = female   name = Merrel
# correct = male     guess = female   name = Micheil
# correct = male     guess = female   name = Michel
# correct = male     guess = female   name = Mickey
# correct = male     guess = female   name = Nate
# correct = male     guess = female   name = Nathan
# correct = male     guess = female   name = Nealson
# correct = male     guess = female   name = Neville
# correct = male     guess = female   name = Nichole
# correct = male     guess = female   name = Pearce
# correct = male     guess = female   name = Pierre
# correct = male     guess = female   name = Radcliffe
# correct = male     guess = female   name = Ravi
# correct = male     guess = female   name = Rickey
# correct = male     guess = female   name = Ritchie
# correct = male     guess = female   name = Si
# correct = male     guess = female   name = Silas
# correct = male     guess = female   name = Spense
# correct = male     guess = female   name = Terrance
# correct = male     guess = female   name = Vasily
# correct = male     guess = female   name = Vijay
# correct = male     guess = female   name = Virgie
# correct = male     guess = female   name = Yanaton
# correct = male     guess = female   name = Yance

# %% [markdown]
# ### Gender Feature 2
# For our second feature extractor, we will use the first one to three, and last one to three letters.

# %%
def features2(name):
    features = {}
    features["firstletter"] = name[0].lower()
    features["lastletter"] = name[-1].lower() 
    features["prefix2"] = name[:2].lower()
    features["prefix3"] = name[:3].lower()
    features["suffix2"] = name[-2:].lower()
    features["suffix3"] = name[-3:].lower()    
    return features

# %%
train_set2 = [(features2(n), gender) for (n, gender) in training]
classifier2 = nltk.NaiveBayesClassifier.train(train_set2)

devtest_set2 = [(features2(n), gender) for (n, gender) in dev_test]
print(nltk.classify.accuracy(classifier2, devtest_set2))
# Out:
# 0.832

# %%
error_analysis(features2)
# Out:
# Number of Errors:  181
# correct = male     guess = female   name = Adolphe
# correct = male     guess = female   name = Adrian
# correct = male     guess = female   name = Agustin
# correct = male     guess = female   name = Ahmad
# correct = male     guess = female   name = Alaa
# correct = male     guess = female   name = Alan
# correct = male     guess = female   name = Aldrich
# correct = male     guess = female   name = Alic
# correct = male     guess = female   name = Alister
# correct = male     guess = female   name = Allah
# correct = male     guess = female   name = Andre
# correct = male     guess = female   name = Archie
# correct = male     guess = female   name = Armstrong
# correct = male     guess = female   name = Artur
# correct = male     guess = female   name = Aubert
# correct = male     guess = female   name = Baird
# correct = male     guess = female   name = Barnabe
# correct = male     guess = female   name = Barrie
# correct = male     guess = female   name = Bear
# correct = male     guess = female   name = Ben
# correct = male     guess = female   name = Benji
# correct = male     guess = female   name = Bennett
# correct = male     guess = female   name = Berk
# correct = male     guess = female   name = Bertram
# correct = male     guess = female   name = Bo
# correct = male     guess = female   name = Boyd
# correct = male     guess = female   name = Brooks
# correct = male     guess = female   name = Casper
# correct = male     guess = female   name = Chris
# correct = male     guess = female   name = Christ
# correct = male     guess = female   name = Christiano
# correct = male     guess = female   name = Constantine
# correct = male     guess = female   name = Cornellis
# correct = male     guess = female   name = Curtis
# correct = male     guess = female   name = Darius
# correct = male     guess = female   name = Derrick
# correct = male     guess = female   name = Devin
# correct = male     guess = female   name = Dewey
# correct = male     guess = female   name = Dexter
# correct = male     guess = female   name = Dion
# correct = male     guess = female   name = Dmitri
# correct = male     guess = female   name = Duffy
# correct = male     guess = female   name = Dunstan
# correct = male     guess = female   name = Durante
# correct = male     guess = female   name = Earl
# correct = male     guess = female   name = Eddie
# correct = male     guess = female   name = Eduard
# correct = male     guess = female   name = Ely
# correct = male     guess = female   name = Emmery
# correct = male     guess = female   name = Emmett
# correct = male     guess = female   name = Ervin
# correct = male     guess = female   name = Ethelbert
# correct = male     guess = female   name = Flipper
# correct = male     guess = female   name = Ford
# correct = male     guess = female   name = Fowler
# correct = male     guess = female   name = Frankie
# correct = male     guess = female   name = Fredric
# correct = male     guess = female   name = Friedric
# correct = male     guess = female   name = Gershom
# correct = male     guess = female   name = Graehme
# correct = male     guess = female   name = Granville
# correct = male     guess = female   name = Greggory
# correct = male     guess = female   name = Hal
# correct = male     guess = female   name = Hamlet
# correct = male     guess = female   name = Hamlin
# correct = male     guess = female   name = Hart
# correct = male     guess = female   name = Hendrik
# correct = male     guess = female   name = Henrik
# correct = male     guess = female   name = Hermann
# correct = male     guess = female   name = Hersh
# correct = male     guess = female   name = Hew
# correct = male     guess = female   name = Higgins
# correct = male     guess = female   name = Homer
# correct = male     guess = female   name = Humbert
# correct = male     guess = female   name = Hunt
# correct = male     guess = female   name = Hymie
# correct = male     guess = female   name = Ian
# correct = male     guess = female   name = Iggie
# correct = male     guess = female   name = Ignazio
# correct = male     guess = female   name = Irvin
# correct = male     guess = female   name = Ivan
# correct = male     guess = female   name = Jedediah
# correct = male     guess = female   name = Jeffie
# correct = male     guess = female   name = Jeromy
# correct = male     guess = female   name = Jervis
# correct = male     guess = female   name = Joachim
# correct = male     guess = female   name = Juan
# correct = male     guess = female   name = Juanita
# correct = male     guess = female   name = Kaiser
# correct = male     guess = female   name = Kenyon
# correct = male     guess = female   name = Lawrence
# correct = male     guess = female   name = Lawton
# correct = male     guess = female   name = Lefty
# correct = male     guess = female   name = Mahesh
# correct = male     guess = female   name = Marius
# correct = male     guess = female   name = Mark
# correct = male     guess = female   name = Maurie
# correct = male     guess = female   name = Maurits
# correct = male     guess = female   name = Maximilien
# correct = male     guess = female   name = Merrel
# correct = male     guess = female   name = Micheil
# correct = male     guess = female   name = Michel
# correct = male     guess = female   name = Mickey
# correct = male     guess = female   name = Mitch
# correct = male     guess = female   name = Moe
# correct = male     guess = female   name = Moishe
# correct = male     guess = female   name = Morton
# correct = male     guess = female   name = Nate
# correct = male     guess = female   name = Nathan
# correct = male     guess = female   name = Nealson
# correct = male     guess = female   name = Ned
# correct = male     guess = female   name = Neville
# correct = male     guess = female   name = Nichole
# correct = male     guess = female   name = Norbert
# correct = male     guess = female   name = Obadiah
# correct = male     guess = female   name = Omar
# correct = male     guess = female   name = Orson
# correct = male     guess = female   name = Osborne
# correct = male     guess = female   name = Oswell
# correct = male     guess = female   name = Owen
# correct = male     guess = female   name = Paton
# correct = male     guess = female   name = Paulo
# correct = male     guess = female   name = Pearce
# correct = male     guess = female   name = Pembroke
# correct = male     guess = female   name = Penrod
# correct = male     guess = female   name = Pete
# correct = male     guess = female   name = Phineas
# correct = male     guess = female   name = Pierre
# correct = male     guess = female   name = Pincas
# correct = male     guess = female   name = Prasun
# correct = male     guess = female   name = Radcliffe
# correct = male     guess = female   name = Randolph
# correct = male     guess = female   name = Ravi
# correct = male     guess = female   name = Rawley
# correct = male     guess = female   name = Rayner
# correct = male     guess = female   name = Redford
# correct = male     guess = female   name = Rhett
# correct = male     guess = female   name = Rickey
# correct = male     guess = female   name = Rik
# correct = male     guess = female   name = Ritchie
# correct = male     guess = female   name = Robb
# correct = male     guess = female   name = Roderic
# correct = male     guess = female   name = Rollin
# correct = male     guess = female   name = Rudy
# correct = male     guess = female   name = Salomo
# correct = male     guess = female   name = Sanderson
# correct = male     guess = female   name = Sargent
# correct = male     guess = female   name = Seymour
# correct = male     guess = female   name = Shepard
# correct = male     guess = female   name = Shepperd
# correct = male     guess = female   name = Si
# correct = male     guess = female   name = Silas
# correct = male     guess = female   name = Simeon
# correct = male     guess = female   name = Skipp
# correct = male     guess = female   name = Spense
# correct = male     guess = female   name = Spiro
# correct = male     guess = female   name = Stanford
# correct = male     guess = female   name = Terrance
# correct = male     guess = female   name = Thaddius
# correct = male     guess = female   name = Thor
# correct = male     guess = female   name = Thurston
# correct = male     guess = female   name = Tracy
# correct = male     guess = female   name = Trip
# correct = male     guess = female   name = Ty
# correct = male     guess = female   name = Urbano
# correct = male     guess = female   name = Vasily
# correct = male     guess = female   name = Vaughan
# correct = male     guess = female   name = Vaughn
# correct = male     guess = female   name = Vijay
# correct = male     guess = female   name = Virgie
# correct = male     guess = female   name = Ward
# correct = male     guess = female   name = Washington
# correct = male     guess = female   name = Weider
# correct = male     guess = female   name = Winny
# correct = male     guess = female   name = Woochang
# correct = male     guess = female   name = Wright
# correct = male     guess = female   name = Wye
# correct = male     guess = female   name = Xymenes
# correct = male     guess = female   name = Yanaton
# correct = male     guess = female   name = Yance
# correct = male     guess = female   name = Yank

# %% [markdown]
# Although the accuracy seems to be way up by more than 7%, this feature extractor is actually worse than the benchmark because it classifies every name as female.

# %% [markdown]
# ### Gender Feature 3
# Let's modify the above feature extractor by counting letters, vowels and checking whether the first and last letters are vowel.

# %%
def features3(name):
    features = {}              
    features["count_letters"] = len(name)
    features["count_vowel"] = len([v for v in name if v in 'aeiou'])
    features["firstletter_is_vowel"] = name[0].lower() in 'aeiou'
    features["lastletter_is_vowel"] = name[-1].lower() in 'aeiou'    
    return features

# %%
train_set3 = [(features3(n), gender) for (n, gender) in training]
classifier3 = nltk.NaiveBayesClassifier.train(train_set3)

devtest_set3 = [(features3(n), gender) for (n, gender) in dev_test]
print(nltk.classify.accuracy(classifier3, devtest_set3))
# Out:
# 0.726

# %%
error_analysis(features3)
# Out:
# Number of Errors:  181
# correct = male     guess = female   name = Adolphe
# correct = male     guess = female   name = Adrian
# correct = male     guess = female   name = Agustin
# correct = male     guess = female   name = Ahmad
# correct = male     guess = female   name = Alaa
# correct = male     guess = female   name = Alan
# correct = male     guess = female   name = Aldrich
# correct = male     guess = female   name = Alic
# correct = male     guess = female   name = Alister
# correct = male     guess = female   name = Allah
# correct = male     guess = female   name = Andre
# correct = male     guess = female   name = Archie
# correct = male     guess = female   name = Armstrong
# correct = male     guess = female   name = Artur
# correct = male     guess = female   name = Aubert
# correct = male     guess = female   name = Baird
# correct = male     guess = female   name = Barnabe
# correct = male     guess = female   name = Barrie
# correct = male     guess = female   name = Bear
# correct = male     guess = female   name = Ben
# correct = male     guess = female   name = Benji
# correct = male     guess = female   name = Bennett
# correct = male     guess = female   name = Berk
# correct = male     guess = female   name = Bertram
# correct = male     guess = female   name = Bo
# correct = male     guess = female   name = Boyd
# correct = male     guess = female   name = Brooks
# correct = male     guess = female   name = Casper
# correct = male     guess = female   name = Chris
# correct = male     guess = female   name = Christ
# correct = male     guess = female   name = Christiano
# correct = male     guess = female   name = Constantine
# correct = male     guess = female   name = Cornellis
# correct = male     guess = female   name = Curtis
# correct = male     guess = female   name = Darius
# correct = male     guess = female   name = Derrick
# correct = male     guess = female   name = Devin
# correct = male     guess = female   name = Dewey
# correct = male     guess = female   name = Dexter
# correct = male     guess = female   name = Dion
# correct = male     guess = female   name = Dmitri
# correct = male     guess = female   name = Duffy
# correct = male     guess = female   name = Dunstan
# correct = male     guess = female   name = Durante
# correct = male     guess = female   name = Earl
# correct = male     guess = female   name = Eddie
# correct = male     guess = female   name = Eduard
# correct = male     guess = female   name = Ely
# correct = male     guess = female   name = Emmery
# correct = male     guess = female   name = Emmett
# correct = male     guess = female   name = Ervin
# correct = male     guess = female   name = Ethelbert
# correct = male     guess = female   name = Flipper
# correct = male     guess = female   name = Ford
# correct = male     guess = female   name = Fowler
# correct = male     guess = female   name = Frankie
# correct = male     guess = female   name = Fredric
# correct = male     guess = female   name = Friedric
# correct = male     guess = female   name = Gershom
# correct = male     guess = female   name = Graehme
# correct = male     guess = female   name = Granville
# correct = male     guess = female   name = Greggory
# correct = male     guess = female   name = Hal
# correct = male     guess = female   name = Hamlet
# correct = male     guess = female   name = Hamlin
# correct = male     guess = female   name = Hart
# correct = male     guess = female   name = Hendrik
# correct = male     guess = female   name = Henrik
# correct = male     guess = female   name = Hermann
# correct = male     guess = female   name = Hersh
# correct = male     guess = female   name = Hew
# correct = male     guess = female   name = Higgins
# correct = male     guess = female   name = Homer
# correct = male     guess = female   name = Humbert
# correct = male     guess = female   name = Hunt
# correct = male     guess = female   name = Hymie
# correct = male     guess = female   name = Ian
# correct = male     guess = female   name = Iggie
# correct = male     guess = female   name = Ignazio
# correct = male     guess = female   name = Irvin
# correct = male     guess = female   name = Ivan
# correct = male     guess = female   name = Jedediah
# correct = male     guess = female   name = Jeffie
# correct = male     guess = female   name = Jeromy
# correct = male     guess = female   name = Jervis
# correct = male     guess = female   name = Joachim
# correct = male     guess = female   name = Juan
# correct = male     guess = female   name = Juanita
# correct = male     guess = female   name = Kaiser
# correct = male     guess = female   name = Kenyon
# correct = male     guess = female   name = Lawrence
# correct = male     guess = female   name = Lawton
# correct = male     guess = female   name = Lefty
# correct = male     guess = female   name = Mahesh
# correct = male     guess = female   name = Marius
# correct = male     guess = female   name = Mark
# correct = male     guess = female   name = Maurie
# correct = male     guess = female   name = Maurits
# correct = male     guess = female   name = Maximilien
# correct = male     guess = female   name = Merrel
# correct = male     guess = female   name = Micheil
# correct = male     guess = female   name = Michel
# correct = male     guess = female   name = Mickey
# correct = male     guess = female   name = Mitch
# correct = male     guess = female   name = Moe
# correct = male     guess = female   name = Moishe
# correct = male     guess = female   name = Morton
# correct = male     guess = female   name = Nate
# correct = male     guess = female   name = Nathan
# correct = male     guess = female   name = Nealson
# correct = male     guess = female   name = Ned
# correct = male     guess = female   name = Neville
# correct = male     guess = female   name = Nichole
# correct = male     guess = female   name = Norbert
# correct = male     guess = female   name = Obadiah
# correct = male     guess = female   name = Omar
# correct = male     guess = female   name = Orson
# correct = male     guess = female   name = Osborne
# correct = male     guess = female   name = Oswell
# correct = male     guess = female   name = Owen
# correct = male     guess = female   name = Paton
# correct = male     guess = female   name = Paulo
# correct = male     guess = female   name = Pearce
# correct = male     guess = female   name = Pembroke
# correct = male     guess = female   name = Penrod
# correct = male     guess = female   name = Pete
# correct = male     guess = female   name = Phineas
# correct = male     guess = female   name = Pierre
# correct = male     guess = female   name = Pincas
# correct = male     guess = female   name = Prasun
# correct = male     guess = female   name = Radcliffe
# correct = male     guess = female   name = Randolph
# correct = male     guess = female   name = Ravi
# correct = male     guess = female   name = Rawley
# correct = male     guess = female   name = Rayner
# correct = male     guess = female   name = Redford
# correct = male     guess = female   name = Rhett
# correct = male     guess = female   name = Rickey
# correct = male     guess = female   name = Rik
# correct = male     guess = female   name = Ritchie
# correct = male     guess = female   name = Robb
# correct = male     guess = female   name = Roderic
# correct = male     guess = female   name = Rollin
# correct = male     guess = female   name = Rudy
# correct = male     guess = female   name = Salomo
# correct = male     guess = female   name = Sanderson
# correct = male     guess = female   name = Sargent
# correct = male     guess = female   name = Seymour
# correct = male     guess = female   name = Shepard
# correct = male     guess = female   name = Shepperd
# correct = male     guess = female   name = Si
# correct = male     guess = female   name = Silas
# correct = male     guess = female   name = Simeon
# correct = male     guess = female   name = Skipp
# correct = male     guess = female   name = Spense
# correct = male     guess = female   name = Spiro
# correct = male     guess = female   name = Stanford
# correct = male     guess = female   name = Terrance
# correct = male     guess = female   name = Thaddius
# correct = male     guess = female   name = Thor
# correct = male     guess = female   name = Thurston
# correct = male     guess = female   name = Tracy
# correct = male     guess = female   name = Trip
# correct = male     guess = female   name = Ty
# correct = male     guess = female   name = Urbano
# correct = male     guess = female   name = Vasily
# correct = male     guess = female   name = Vaughan
# correct = male     guess = female   name = Vaughn
# correct = male     guess = female   name = Vijay
# correct = male     guess = female   name = Virgie
# correct = male     guess = female   name = Ward
# correct = male     guess = female   name = Washington
# correct = male     guess = female   name = Weider
# correct = male     guess = female   name = Winny
# correct = male     guess = female   name = Woochang
# correct = male     guess = female   name = Wright
# correct = male     guess = female   name = Wye
# correct = male     guess = female   name = Xymenes
# correct = male     guess = female   name = Yanaton
# correct = male     guess = female   name = Yance
# correct = male     guess = female   name = Yank

# %% [markdown]
# The accuracy is even worse, and all names are once again classified as female.

# %% [markdown]
# ### Gender Feature 4
# Instead of identifying vowels, let's combine useful features from the features1, 2 and 3 and see if we can do better.

# %%
def features4(name):
    features = {}              
    features["first_letter"] = name[0].lower()
    features["last_letter"] = name[-1].lower()
    features["count_letters"] = len(name)    
    for letter in "abcdefghijklmnopqrstuvwxyz":
        features["count({})".format(letter)] = name.lower().count(letter)
        features["has({})".format(letter)] = (letter in name.lower())        
    features["prefix2"] = name[:2].lower()
    features["prefix3"] = name[:3].lower()
    features["suffix2"] = name[-2:].lower()
    features["suffix3"] = name[-3:].lower()        
    return features

# %%
train_set4 = [(features4(n), gender) for (n, gender) in training]
classifier4 = nltk.NaiveBayesClassifier.train(train_set4)

devtest_set4 = [(features4(n), gender) for (n, gender) in dev_test]
print(nltk.classify.accuracy(classifier4, devtest_set4))
# Out:
# 0.822

# %%
error_analysis(features4)
# Out:
# Number of Errors:  121
# correct = female   guess = male     name = Ardyth
# correct = female   guess = male     name = Audry
# correct = female   guess = male     name = Bird
# correct = female   guess = male     name = Bridget
# correct = female   guess = male     name = Brooke
# correct = female   guess = male     name = Brynn
# correct = female   guess = male     name = Charis
# correct = female   guess = male     name = Chery
# correct = female   guess = male     name = Christin
# correct = female   guess = male     name = Corry
# correct = female   guess = male     name = Darb
# correct = female   guess = male     name = Dorolice
# correct = female   guess = male     name = Fawne
# correct = female   guess = male     name = Gennifer
# correct = female   guess = male     name = Gretchen
# correct = female   guess = male     name = Guenevere
# correct = female   guess = male     name = Heath
# correct = female   guess = male     name = Ingaberg
# correct = female   guess = male     name = Ingrid
# correct = female   guess = male     name = Justin
# correct = female   guess = male     name = Kaster
# correct = female   guess = male     name = Kim
# correct = female   guess = male     name = Kore
# correct = female   guess = male     name = Leanor
# correct = female   guess = male     name = Mag
# correct = female   guess = male     name = Mair
# correct = female   guess = male     name = Marget
# correct = female   guess = male     name = Margret
# correct = female   guess = male     name = Marys
# correct = female   guess = male     name = Mikako
# correct = female   guess = male     name = Modesty
# correct = female   guess = male     name = Myrah
# correct = female   guess = male     name = Nert
# correct = female   guess = male     name = Olly
# correct = female   guess = male     name = Pearl
# correct = female   guess = male     name = Pen
# correct = female   guess = male     name = Persis
# correct = female   guess = male     name = Pet
# correct = female   guess = male     name = Rhiamon
# correct = female   guess = male     name = Rhodie
# correct = female   guess = male     name = Rivkah
# correct = female   guess = male     name = Roby
# correct = female   guess = male     name = Ros
# correct = female   guess = male     name = Rosaleen
# correct = female   guess = male     name = Rosalynd
# correct = female   guess = male     name = Rosamond
# correct = female   guess = male     name = Rosie
# correct = female   guess = male     name = Shawn
# correct = female   guess = male     name = Sinead
# correct = female   guess = male     name = Tatum
# correct = female   guess = male     name = Thomasin
# correct = female   guess = male     name = Tobi
# correct = female   guess = male     name = Tomi
# correct = female   guess = male     name = Tommy
# correct = female   guess = male     name = Tony
# correct = female   guess = male     name = Trixy
# correct = female   guess = male     name = Winne
# correct = female   guess = male     name = Wynny
# correct = female   guess = male     name = Yehudit
# correct = male     guess = female   name = Adrian
# correct = male     guess = female   name = Alaa
# correct = male     guess = female   name = Alan
# correct = male     guess = female   name = Aldrich
# correct = male     guess = female   name = Alister
# correct = male     guess = female   name = Allah
# correct = male     guess = female   name = Andre
# correct = male     guess = female   name = Archie
# correct = male     guess = female   name = Barnabe
# correct = male     guess = female   name = Barrie
# correct = male     guess = female   name = Benji
# correct = male     guess = female   name = Bennett
# correct = male     guess = female   name = Constantine
# correct = male     guess = female   name = Devin
# correct = male     guess = female   name = Dmitri
# correct = male     guess = female   name = Earl
# correct = male     guess = female   name = Eddie
# correct = male     guess = female   name = Ely
# correct = male     guess = female   name = Emmery
# correct = male     guess = female   name = Ervin
# correct = male     guess = female   name = Frankie
# correct = male     guess = female   name = Graehme
# correct = male     guess = female   name = Granville
# correct = male     guess = female   name = Hamlin
# correct = male     guess = female   name = Hymie
# correct = male     guess = female   name = Ian
# correct = male     guess = female   name = Iggie
# correct = male     guess = female   name = Ivan
# correct = male     guess = female   name = Jedediah
# correct = male     guess = female   name = Jeffie
# correct = male     guess = female   name = Juan
# correct = male     guess = female   name = Juanita
# correct = male     guess = female   name = Kaiser
# correct = male     guess = female   name = Kenyon
# correct = male     guess = female   name = Lawrence
# correct = male     guess = female   name = Lefty
# correct = male     guess = female   name = Maurie
# correct = male     guess = female   name = Maximilien
# correct = male     guess = female   name = Merrel
# correct = male     guess = female   name = Micheil
# correct = male     guess = female   name = Michel
# correct = male     guess = female   name = Mickey
# correct = male     guess = female   name = Nate
# correct = male     guess = female   name = Nathan
# correct = male     guess = female   name = Nealson
# correct = male     guess = female   name = Neville
# correct = male     guess = female   name = Nichole
# correct = male     guess = female   name = Pearce
# correct = male     guess = female   name = Pierre
# correct = male     guess = female   name = Radcliffe
# correct = male     guess = female   name = Ravi
# correct = male     guess = female   name = Rickey
# correct = male     guess = female   name = Ritchie
# correct = male     guess = female   name = Si
# correct = male     guess = female   name = Silas
# correct = male     guess = female   name = Spense
# correct = male     guess = female   name = Terrance
# correct = male     guess = female   name = Vasily
# correct = male     guess = female   name = Vijay
# correct = male     guess = female   name = Virgie
# correct = male     guess = female   name = Yanaton
# correct = male     guess = female   name = Yance

# %% [markdown]
# The result is much better and has the best accuracy among the 4 feature extractors that we have built. Let's apply it on our test set.

# %% [markdown]
# ## Gender Features 5

# %% [markdown]
# ### Additional Feature Engineering Based off of this work:
# https://arxiv.org/pdf/1606.05467.pdf

# %% [markdown]
# ### In this feature generation instead of just looking the prescence and count of every character instead I opted to group characters by Kiki and Bouba characters which are groupings of letters based off the way they are pronounced

# %% [markdown]
# ### I found some interesting reading on Bouba vs Kiki as well
# https://en.wikipedia.org/wiki/Bouba/kiki_effect
# https://www.scientificamerican.com/article/bring-science-home-bouba-kiki-effect/

# %% [markdown]
# In the feature engineering below I aslo brought in the syllable count as well

# %%
def syllable_count(word):
    word = word.lower()
    count = 0
    vowels = "aeiouy"
    if word[0] in vowels:
        count += 1
    for index in range(1, len(word)):
        if word[index] in vowels and word[index - 1] not in vowels:
            count += 1
    if word.endswith("e"):
        count -= 1
    if count == 0:
        count += 1
    return count

# %%
def features5(name):
    features = {}              
    features["first_letter"] = name[0].lower()
    features["last_letter"] = name[-1].lower()
    features["count_letters"] = len(name)    
    #for letter in "abcdefghijklmnopqrstuvwxyz":
    #    features["count({})".format(letter)] = name.lower().count(letter)
    #    features["has({})".format(letter)] = (letter in name.lower())        
    features["prefix2"] = name[:2].lower()
    features["prefix3"] = name[:3].lower()
    features["suffix2"] = name[-2:].lower()
    features["suffix3"] = name[-3:].lower()
    features["bouba_letters"] = len([v for v in name if v in 'blmnuo'])
    features["kiki_letters"] = len([v for v in name if v in 'kptiezv'])
    features["syllable_count"] = syllable_count(name)

    return features

# %%
train_set5 = [(features5(n), gender) for (n, gender) in training]
classifier5 = nltk.NaiveBayesClassifier.train(train_set5)

devtest_set5 = [(features5(n), gender) for (n, gender) in dev_test]
print(nltk.classify.accuracy(classifier5, devtest_set5))
# Out:
# 0.844

# %% [markdown]
# ## Trying out Support Vector Machine

# %%
import nltk.classify
from sklearn.svm import LinearSVC

classifier = nltk.classify.SklearnClassifier(LinearSVC())

train_set6 = [(features5(n), gender) for (n, gender) in training]
classifier6 = classifier.train(train_set6)

devtest_set6 = [(features5(n), gender) for (n, gender) in dev_test]
print(nltk.classify.accuracy(classifier6, devtest_set6))
# Out:
# 0.816

# %% [markdown]
# ### Ultimately the support vector machine does not do as well as the naive bayes

# %% [markdown]
# ## Test set
# Let's compare the features1 (benchmark) with features4 using the test set. We have made some improvement!

# %%
test_set1 = [(features1(n), gender) for (n, gender) in test]
test_set5 = [(features5(n), gender) for (n, gender) in test]

print('The accuracy using features1 (benchmark) is ' + \
      str(nltk.classify.accuracy(classifier, test_set1)))

print('The accuracy using features5 is ' + \
      str(nltk.classify.accuracy(classifier5, test_set5)))
# Out:
# The accuracy using features1 (benchmark) is 0.744
# The accuracy using features5 is 0.834

# %% [markdown]
# ## Take a look at the Most Informative Features

# %%
classifier5.show_most_informative_features(500)
# Out:
# Most Informative Features
#                  suffix2 = 'na'           female : male   =    157.4 : 1.0
#                  suffix2 = 'la'           female : male   =     69.8 : 1.0
#                  suffix2 = 'ta'           female : male   =     43.3 : 1.0
#              last_letter = 'k'              male : female =     41.3 : 1.0
#                  suffix2 = 'ld'             male : female =     39.7 : 1.0
#                  suffix2 = 'us'             male : female =     39.2 : 1.0
#              last_letter = 'a'            female : male   =     37.2 : 1.0
#                  suffix2 = 'ia'           female : male   =     37.1 : 1.0
#                  suffix2 = 'sa'           female : male   =     32.4 : 1.0
#                  suffix2 = 'rt'             male : female =     29.8 : 1.0
#                  suffix2 = 'rd'             male : female =     28.5 : 1.0
#                  suffix2 = 'do'             male : female =     26.3 : 1.0
#                  suffix3 = 'ita'          female : male   =     25.8 : 1.0
#                  suffix3 = 'ana'          female : male   =     24.9 : 1.0
#                  suffix2 = 'ra'           female : male   =     24.0 : 1.0
#                  suffix2 = 'ch'             male : female =     22.9 : 1.0
#                  suffix3 = 'ard'            male : female =     19.9 : 1.0
#                  suffix3 = 'nne'          female : male   =     18.5 : 1.0
#                  prefix3 = 'dor'          female : male   =     16.4 : 1.0
#                  prefix3 = 'mel'          female : male   =     15.9 : 1.0
#              last_letter = 'f'              male : female =     15.4 : 1.0
#                  suffix3 = 'ert'            male : female =     15.3 : 1.0
#                  prefix2 = 'hu'             male : female =     15.1 : 1.0
#                  suffix2 = 'im'             male : female =     15.1 : 1.0
#                  suffix2 = 'io'             male : female =     14.4 : 1.0
#                  prefix3 = 'tha'            male : female =     14.1 : 1.0
#                  suffix2 = 'ka'           female : male   =     14.1 : 1.0
#                  suffix3 = 'ria'          female : male   =     13.4 : 1.0
#                  suffix3 = 'ela'          female : male   =     13.0 : 1.0
#                  suffix2 = 'ea'           female : male   =     12.1 : 1.0
#                  prefix3 = 'cat'          female : male   =     12.1 : 1.0
#                  suffix3 = 'mon'            male : female =     12.0 : 1.0
#                  suffix3 = 'son'            male : female =     11.3 : 1.0
#                  suffix3 = 'dra'          female : male   =     11.3 : 1.0
#                  suffix3 = 'nni'          female : male   =     10.9 : 1.0
#              last_letter = 'd'              male : female =     10.7 : 1.0
#                  prefix2 = 'tu'             male : female =     10.6 : 1.0
#                  prefix2 = 'ty'             male : female =     10.6 : 1.0
#                  suffix2 = 'ns'             male : female =     10.6 : 1.0
#                  suffix2 = 'rn'             male : female =     10.6 : 1.0
#              last_letter = 'm'              male : female =     10.3 : 1.0
#                  suffix2 = 'ya'           female : male   =     10.1 : 1.0
#                  prefix3 = 'gar'            male : female =     10.1 : 1.0
#                  suffix3 = 'ias'            male : female =      9.9 : 1.0
#              last_letter = 'v'              male : female =      9.9 : 1.0
#                  suffix2 = 'on'             male : female =      9.8 : 1.0
#                  suffix3 = 'lle'          female : male   =      9.6 : 1.0
#                  suffix2 = 'ul'             male : female =      9.5 : 1.0
#                  suffix2 = 'ti'           female : male   =      9.4 : 1.0
#                  suffix3 = 'ter'            male : female =      9.2 : 1.0
#                  prefix3 = 'ros'          female : male   =      9.0 : 1.0
#                  prefix2 = 'wa'             male : female =      9.0 : 1.0
#                  prefix3 = 'bro'            male : female =      8.9 : 1.0
#                  prefix3 = 'par'            male : female =      8.9 : 1.0
#                  suffix3 = 'den'            male : female =      8.9 : 1.0
#                  suffix3 = 'dor'            male : female =      8.9 : 1.0
#                  suffix3 = 'cia'          female : male   =      8.7 : 1.0
#              last_letter = 'o'              male : female =      8.6 : 1.0
#              last_letter = 'p'              male : female =      8.5 : 1.0
#                  suffix2 = 'te'           female : male   =      8.5 : 1.0
#                  suffix3 = 'vin'            male : female =      8.4 : 1.0
#                  prefix2 = 'fo'             male : female =      8.4 : 1.0
#                  suffix2 = 'ro'             male : female =      8.4 : 1.0
#                  suffix2 = 'ff'             male : female =      8.4 : 1.0
#                  suffix3 = 'lli'          female : male   =      7.9 : 1.0
#                  suffix2 = 'as'             male : female =      7.9 : 1.0
#                  prefix3 = 'mal'          female : male   =      7.9 : 1.0
#                  prefix3 = 'cli'            male : female =      7.8 : 1.0
#                  prefix3 = 'god'            male : female =      7.8 : 1.0
#                  suffix3 = 'lan'            male : female =      7.8 : 1.0
#                  suffix3 = 'uel'            male : female =      7.8 : 1.0
#                  suffix3 = 'und'            male : female =      7.8 : 1.0
#                  suffix3 = 'ven'            male : female =      7.8 : 1.0
#                  suffix2 = 'em'             male : female =      7.7 : 1.0
#                  suffix3 = 'ene'          female : male   =      7.6 : 1.0
#                  suffix3 = 'isa'          female : male   =      7.5 : 1.0
#                  suffix2 = 'er'             male : female =      7.5 : 1.0
#                  prefix2 = 'wh'             male : female =      7.3 : 1.0
#                  suffix2 = 'lo'             male : female =      7.3 : 1.0
#                  suffix2 = 'ip'             male : female =      7.3 : 1.0
#                  suffix2 = 'rk'             male : female =      7.3 : 1.0
#                  suffix2 = 'st'             male : female =      7.3 : 1.0
#                  suffix3 = 'bel'          female : male   =      7.0 : 1.0
#                  suffix2 = 'si'           female : male   =      7.0 : 1.0
#                  suffix2 = 'am'             male : female =      6.8 : 1.0
#                  prefix3 = 'kin'            male : female =      6.8 : 1.0
#                  prefix3 = 'sau'            male : female =      6.8 : 1.0
#                  suffix3 = 'rge'            male : female =      6.8 : 1.0
#              last_letter = 'r'              male : female =      6.8 : 1.0
#                  prefix3 = 'flo'          female : male   =      6.8 : 1.0
#                  suffix3 = 'ree'          female : male   =      6.6 : 1.0
#                  suffix2 = 'ar'             male : female =      6.5 : 1.0
#                  prefix3 = 'jan'          female : male   =      6.5 : 1.0
#                  suffix3 = 'ine'          female : male   =      6.4 : 1.0
#                  suffix2 = 'sh'             male : female =      6.4 : 1.0
#                  suffix2 = 'ud'             male : female =      6.4 : 1.0
#                  suffix2 = 'sy'           female : male   =      6.3 : 1.0
#                  suffix2 = 'ke'             male : female =      6.3 : 1.0
#                  prefix2 = 'ka'           female : male   =      6.3 : 1.0
#                  suffix3 = 'ryn'          female : male   =      6.2 : 1.0
#                  suffix3 = 'ssy'          female : male   =      6.2 : 1.0
#                  suffix3 = 'sta'          female : male   =      6.2 : 1.0
#                  prefix3 = 'ama'          female : male   =      6.2 : 1.0
#                  prefix3 = 'hel'          female : male   =      6.2 : 1.0
#                  suffix2 = 'eb'             male : female =      6.1 : 1.0
#                  suffix2 = 'ev'             male : female =      6.1 : 1.0
#                  suffix2 = 'oy'             male : female =      6.1 : 1.0
#                  prefix3 = 'wal'            male : female =      6.1 : 1.0
#                  suffix3 = 'lyn'          female : male   =      6.1 : 1.0
#                  suffix3 = 'lee'          female : male   =      6.0 : 1.0
#                  prefix3 = 'ken'            male : female =      6.0 : 1.0
#                  suffix2 = 'di'           female : male   =      5.9 : 1.0
#                  prefix2 = 'we'             male : female =      5.8 : 1.0
#                  prefix3 = 'bur'            male : female =      5.8 : 1.0
#                  prefix3 = 'whi'            male : female =      5.8 : 1.0
#                  suffix3 = 'and'            male : female =      5.7 : 1.0
#                  suffix3 = 'lem'            male : female =      5.7 : 1.0
#                  suffix3 = 'ler'            male : female =      5.7 : 1.0
#                  suffix3 = 'nan'            male : female =      5.7 : 1.0
#                  prefix3 = 'bel'          female : male   =      5.7 : 1.0
#                  suffix2 = 'ew'             male : female =      5.7 : 1.0
#                  suffix2 = 'ir'             male : female =      5.7 : 1.0
#                  suffix2 = 'ed'             male : female =      5.6 : 1.0
#                  prefix2 = 'ce'           female : male   =      5.6 : 1.0
#              last_letter = 'g'              male : female =      5.5 : 1.0
#                  suffix2 = 'nd'             male : female =      5.5 : 1.0
#                  suffix3 = 'tha'          female : male   =      5.5 : 1.0
#                  prefix3 = 'rod'            male : female =      5.4 : 1.0
#                  suffix3 = 'sie'          female : male   =      5.4 : 1.0
#                  prefix3 = 'alf'            male : female =      5.3 : 1.0
#                  suffix3 = 'ira'          female : male   =      5.3 : 1.0
#                  suffix3 = 'ndi'          female : male   =      5.3 : 1.0
#                  prefix3 = 'gen'          female : male   =      5.3 : 1.0
#                  prefix3 = 'myr'          female : male   =      5.3 : 1.0
#                  suffix2 = 'ni'           female : male   =      5.3 : 1.0
#                  prefix3 = 'jen'          female : male   =      5.2 : 1.0
#                  prefix3 = 'tho'            male : female =      5.2 : 1.0
#              last_letter = 'z'              male : female =      5.1 : 1.0
#                  prefix2 = 'dr'             male : female =      5.0 : 1.0
#                  suffix2 = 'es'             male : female =      5.0 : 1.0
#                  suffix2 = 'go'             male : female =      5.0 : 1.0
#                  suffix2 = 'ig'             male : female =      5.0 : 1.0
#                  suffix2 = 'ee'           female : male   =      5.0 : 1.0
#                  suffix3 = 'sha'          female : male   =      5.0 : 1.0
#                  suffix3 = 'dee'          female : male   =      4.9 : 1.0
#                  suffix3 = 'nah'          female : male   =      4.9 : 1.0
#                  suffix2 = 'ye'           female : male   =      4.9 : 1.0
#                  prefix3 = 'kor'          female : male   =      4.9 : 1.0
#                  prefix3 = 'sib'          female : male   =      4.9 : 1.0
#                  suffix2 = 'or'             male : female =      4.8 : 1.0
#              last_letter = 'w'              male : female =      4.8 : 1.0
#                  suffix3 = 'ise'          female : male   =      4.7 : 1.0
#                  suffix2 = 'ha'           female : male   =      4.7 : 1.0
#                  prefix3 = 'eng'            male : female =      4.7 : 1.0
#                  prefix3 = 'hay'            male : female =      4.7 : 1.0
#                  prefix3 = 'hor'            male : female =      4.7 : 1.0
#                  prefix3 = 'mos'            male : female =      4.7 : 1.0
#                  prefix3 = 'nev'            male : female =      4.7 : 1.0
#                  prefix3 = 'qui'            male : female =      4.7 : 1.0
#                  prefix3 = 'say'            male : female =      4.7 : 1.0
#                  prefix3 = 'sig'            male : female =      4.7 : 1.0
#                  prefix3 = 'sol'            male : female =      4.7 : 1.0
#                  prefix3 = 'teo'            male : female =      4.7 : 1.0
#             first_letter = 'w'              male : female =      4.7 : 1.0
#                  suffix3 = 'ery'            male : female =      4.7 : 1.0
#                  suffix3 = 'ott'            male : female =      4.7 : 1.0
#                  suffix3 = 'van'            male : female =      4.7 : 1.0
#                  suffix3 = 'air'            male : female =      4.7 : 1.0
#                  suffix3 = 'ake'            male : female =      4.7 : 1.0
#                  suffix3 = 'ber'            male : female =      4.7 : 1.0
#                  suffix3 = 'bin'            male : female =      4.7 : 1.0
#                  suffix3 = 'hon'            male : female =      4.7 : 1.0
#                  suffix3 = 'iff'            male : female =      4.7 : 1.0
#                  suffix3 = 'per'            male : female =      4.7 : 1.0
#                  suffix3 = 'von'            male : female =      4.7 : 1.0
#                  suffix3 = 'ann'          female : male   =      4.6 : 1.0
#                  prefix3 = 'lor'          female : male   =      4.6 : 1.0
#                  suffix2 = 'eo'             male : female =      4.5 : 1.0
#                  suffix3 = 'ika'          female : male   =      4.5 : 1.0
#                  suffix3 = 'lah'          female : male   =      4.5 : 1.0
#                  suffix3 = 'tti'          female : male   =      4.5 : 1.0
#                  prefix3 = 'ric'            male : female =      4.4 : 1.0
#                  prefix3 = 'dav'            male : female =      4.4 : 1.0
#                  suffix3 = 'ain'            male : female =      4.3 : 1.0
#                  prefix3 = 'kar'          female : male   =      4.3 : 1.0
#                  suffix2 = 'yn'           female : male   =      4.3 : 1.0
#                  suffix3 = 'rne'            male : female =      4.2 : 1.0
#                  suffix2 = 'nt'             male : female =      4.2 : 1.0
#                  prefix3 = 'her'            male : female =      4.2 : 1.0
#              last_letter = 's'              male : female =      4.2 : 1.0
#                  prefix3 = 'ali'          female : male   =      4.2 : 1.0
#              last_letter = 't'              male : female =      4.2 : 1.0
#                  prefix2 = 'es'           female : male   =      4.2 : 1.0
#                  prefix3 = 'mat'            male : female =      4.1 : 1.0
#             kiki_letters = 6              female : male   =      4.1 : 1.0
#                  prefix3 = 'dom'            male : female =      4.1 : 1.0
#                  prefix3 = 'for'            male : female =      4.1 : 1.0
#                  suffix3 = 'ger'            male : female =      4.1 : 1.0
#                  suffix3 = 'las'            male : female =      4.1 : 1.0
#                  suffix3 = 'ond'            male : female =      4.1 : 1.0
#                  suffix3 = 'hea'          female : male   =      4.0 : 1.0
#                  suffix3 = 'sse'          female : male   =      4.0 : 1.0
#                  prefix3 = 'adr'          female : male   =      4.0 : 1.0
#                  prefix3 = 'dev'          female : male   =      4.0 : 1.0
#                  prefix3 = 'lee'          female : male   =      4.0 : 1.0
#                  prefix3 = 'sar'          female : male   =      4.0 : 1.0
#                  prefix3 = 'shi'          female : male   =      4.0 : 1.0
#                  prefix3 = 'tre'            male : female =      4.0 : 1.0
#                  suffix3 = 'her'            male : female =      4.0 : 1.0
#                  suffix3 = 'iah'            male : female =      4.0 : 1.0
#                  suffix3 = 'ron'            male : female =      4.0 : 1.0
#              last_letter = 'j'              male : female =      4.0 : 1.0
#              last_letter = 'u'              male : female =      4.0 : 1.0
#                  prefix2 = 'ze'             male : female =      3.9 : 1.0
#                  prefix3 = 'mad'          female : male   =      3.9 : 1.0
#                  suffix2 = 'ax'             male : female =      3.9 : 1.0
#                  suffix2 = 'ex'             male : female =      3.9 : 1.0
#                  suffix2 = 'so'             male : female =      3.9 : 1.0
#                  prefix3 = 'bri'          female : male   =      3.9 : 1.0
#                  prefix2 = 'bu'             male : female =      3.8 : 1.0
#                  suffix2 = 'ad'             male : female =      3.8 : 1.0
#                  prefix2 = 'fa'           female : male   =      3.7 : 1.0
#                  prefix3 = 'lyn'          female : male   =      3.7 : 1.0
#                  suffix2 = 'ne'           female : male   =      3.7 : 1.0
#                  prefix3 = 'die'            male : female =      3.7 : 1.0
#                  prefix3 = 'joh'            male : female =      3.7 : 1.0
#                  prefix3 = 'nil'            male : female =      3.7 : 1.0
#                  prefix3 = 'noa'            male : female =      3.7 : 1.0
#                  prefix3 = 'ral'            male : female =      3.7 : 1.0
#                  prefix3 = 'rem'            male : female =      3.7 : 1.0
#                  prefix3 = 'sco'            male : female =      3.7 : 1.0
#                  suffix3 = 'ale'            male : female =      3.6 : 1.0
#                  suffix3 = 'aud'            male : female =      3.6 : 1.0
#                  suffix3 = 'ens'            male : female =      3.6 : 1.0
#                  suffix3 = 'evy'            male : female =      3.6 : 1.0
#                  suffix3 = 'gus'            male : female =      3.6 : 1.0
#                  suffix3 = 'iot'            male : female =      3.6 : 1.0
#                  suffix3 = 'itt'            male : female =      3.6 : 1.0
#                  suffix3 = 'lby'            male : female =      3.6 : 1.0
#                  suffix3 = 'lon'            male : female =      3.6 : 1.0
#                  suffix3 = 'meo'            male : female =      3.6 : 1.0
#                  suffix3 = 'nky'            male : female =      3.6 : 1.0
#                  suffix3 = 'oel'            male : female =      3.6 : 1.0
#                  suffix3 = 'ome'            male : female =      3.6 : 1.0
#                  suffix3 = 'rio'            male : female =      3.6 : 1.0
#                  suffix3 = 'sel'            male : female =      3.6 : 1.0
#                  suffix3 = 'ule'            male : female =      3.6 : 1.0
#                  suffix3 = 'vey'            male : female =      3.6 : 1.0
#                  suffix3 = 'nee'          female : male   =      3.6 : 1.0
#                  prefix3 = 'edi'          female : male   =      3.6 : 1.0
#                  prefix3 = 'pau'          female : male   =      3.6 : 1.0
#                  prefix3 = 'bar'            male : female =      3.6 : 1.0
#              last_letter = 'i'            female : male   =      3.6 : 1.0
#              last_letter = 'b'              male : female =      3.5 : 1.0
#                  prefix2 = 'gl'           female : male   =      3.5 : 1.0
#                  prefix2 = 'za'             male : female =      3.5 : 1.0
#                  prefix3 = 'jac'          female : male   =      3.5 : 1.0
#                  prefix3 = 'ave'            male : female =      3.5 : 1.0
#                  prefix3 = 'gio'            male : female =      3.5 : 1.0
#                  prefix3 = 'pie'            male : female =      3.5 : 1.0
#                  prefix3 = 'ram'            male : female =      3.5 : 1.0
#                  suffix3 = 'ari'          female : male   =      3.5 : 1.0
#                  suffix3 = 'are'            male : female =      3.4 : 1.0
#                  prefix3 = 'cri'          female : male   =      3.4 : 1.0
#             kiki_letters = 5              female : male   =      3.4 : 1.0
#                  prefix2 = 'ky'           female : male   =      3.4 : 1.0
#                  suffix3 = 'han'            male : female =      3.4 : 1.0
#                  suffix3 = 'mar'            male : female =      3.4 : 1.0
#             first_letter = 'q'              male : female =      3.3 : 1.0
#                  suffix3 = 'ace'            male : female =      3.3 : 1.0
#                  suffix3 = 'rie'          female : male   =      3.3 : 1.0
#                  prefix2 = 'qu'             male : female =      3.2 : 1.0
#                  suffix2 = 'bi'           female : male   =      3.2 : 1.0
#                  suffix3 = 'ani'          female : male   =      3.2 : 1.0
#                  suffix3 = 'bbi'          female : male   =      3.2 : 1.0
#                  suffix3 = 'bey'          female : male   =      3.2 : 1.0
#                  suffix3 = 'dis'          female : male   =      3.2 : 1.0
#                  suffix3 = 'hie'          female : male   =      3.2 : 1.0
#                  prefix3 = 'far'          female : male   =      3.2 : 1.0
#                  prefix3 = 'job'          female : male   =      3.2 : 1.0
#                  prefix3 = 'kas'          female : male   =      3.2 : 1.0
#                  prefix3 = 'lar'          female : male   =      3.2 : 1.0
#                  prefix3 = 'mai'          female : male   =      3.2 : 1.0
#                  prefix3 = 'ore'          female : male   =      3.2 : 1.0
#                  prefix2 = 'ul'             male : female =      3.2 : 1.0
#                  prefix2 = 'li'           female : male   =      3.2 : 1.0
#           syllable_count = 4              female : male   =      3.1 : 1.0
#                  prefix2 = 'na'           female : male   =      3.1 : 1.0
#                  suffix2 = 'pe'             male : female =      3.1 : 1.0
#                  prefix2 = 'ly'           female : male   =      3.1 : 1.0
#                  prefix2 = 'ha'             male : female =      3.1 : 1.0
#                  prefix2 = 'th'             male : female =      3.1 : 1.0
#                  prefix3 = 'val'          female : male   =      3.0 : 1.0
#                  suffix2 = 'ai'             male : female =      3.0 : 1.0
#                  prefix2 = 'ba'             male : female =      3.0 : 1.0
#                  suffix3 = 'ddy'            male : female =      3.0 : 1.0
#                  suffix2 = 'ae'           female : male   =      3.0 : 1.0
#                  suffix2 = 'ba'           female : male   =      3.0 : 1.0
#                  suffix2 = 'ko'           female : male   =      3.0 : 1.0
#                  suffix2 = 'za'           female : male   =      3.0 : 1.0
#                  suffix3 = 'red'            male : female =      3.0 : 1.0
#                  suffix3 = 'ile'          female : male   =      2.9 : 1.0
#                  prefix3 = 'cor'          female : male   =      2.9 : 1.0
#                  prefix3 = 'aug'            male : female =      2.9 : 1.0
#                  prefix3 = 'jon'            male : female =      2.9 : 1.0
#                  suffix3 = 'ail'            male : female =      2.9 : 1.0
#                  suffix3 = 'ier'            male : female =      2.9 : 1.0
#                  suffix3 = 'igh'            male : female =      2.9 : 1.0
#                  prefix2 = 'ru'             male : female =      2.9 : 1.0
#                  prefix2 = 'go'             male : female =      2.9 : 1.0
#                  prefix3 = 'pat'            male : female =      2.8 : 1.0
#                  prefix3 = 'fil'            male : female =      2.8 : 1.0
#                  prefix3 = 'fle'            male : female =      2.8 : 1.0
#                  prefix3 = 'gav'            male : female =      2.8 : 1.0
#                  prefix3 = 'ser'            male : female =      2.8 : 1.0
#                  suffix3 = 'ose'            male : female =      2.8 : 1.0
#                  prefix2 = 'ag'           female : male   =      2.8 : 1.0
#                  prefix2 = 'ca'           female : male   =      2.8 : 1.0
#                  suffix2 = 'li'           female : male   =      2.8 : 1.0
#                  prefix2 = 'aj'             male : female =      2.8 : 1.0
#                  prefix2 = 'ia'             male : female =      2.8 : 1.0
#             first_letter = 'u'              male : female =      2.8 : 1.0
#                  suffix2 = 'af'             male : female =      2.8 : 1.0
#                  suffix2 = 'ag'             male : female =      2.8 : 1.0
#                  suffix2 = 'ez'             male : female =      2.8 : 1.0
#                  suffix2 = 'nk'             male : female =      2.8 : 1.0
#                  suffix2 = 'rr'             male : female =      2.8 : 1.0
#                  suffix2 = 'we'             male : female =      2.8 : 1.0
#                  suffix3 = 'cki'          female : male   =      2.8 : 1.0
#                  suffix3 = 'eri'          female : male   =      2.8 : 1.0
#                  suffix3 = 'xie'          female : male   =      2.8 : 1.0
#                  suffix3 = 'ill'            male : female =      2.8 : 1.0
#                  prefix3 = 'cec'          female : male   =      2.8 : 1.0
#                  prefix3 = 'eva'          female : male   =      2.8 : 1.0
#                  prefix3 = 'kyl'          female : male   =      2.8 : 1.0
#                  prefix3 = 'lia'          female : male   =      2.8 : 1.0
#                  prefix3 = 'tri'          female : male   =      2.8 : 1.0
#                  prefix3 = 'tru'          female : male   =      2.8 : 1.0
#                  prefix3 = 'urs'          female : male   =      2.8 : 1.0
#                  suffix2 = 'tt'             male : female =      2.7 : 1.0
#                  suffix2 = 'ay'             male : female =      2.7 : 1.0
#                  suffix2 = 'an'             male : female =      2.7 : 1.0
#                  suffix3 = 'nce'            male : female =      2.7 : 1.0
#                  prefix3 = 'san'            male : female =      2.7 : 1.0
#                  prefix3 = 'tor'            male : female =      2.7 : 1.0
#                  prefix2 = 'bl'           female : male   =      2.7 : 1.0
#                  suffix2 = 'id'             male : female =      2.7 : 1.0
#                  prefix3 = 'car'          female : male   =      2.7 : 1.0
#                  prefix3 = 'sel'          female : male   =      2.7 : 1.0
#                  prefix2 = 'sc'             male : female =      2.6 : 1.0
#                  prefix3 = 'kri'          female : male   =      2.6 : 1.0
#                  prefix2 = 'ko'           female : male   =      2.6 : 1.0
#                  suffix2 = 'oe'             male : female =      2.6 : 1.0
#                  prefix3 = 'abr'            male : female =      2.6 : 1.0
#                  prefix3 = 'aja'            male : female =      2.6 : 1.0
#                  prefix3 = 'alp'            male : female =      2.6 : 1.0
#                  prefix3 = 'edw'            male : female =      2.6 : 1.0
#                  prefix3 = 'elm'            male : female =      2.6 : 1.0
#                  prefix3 = 'era'            male : female =      2.6 : 1.0
#                  prefix3 = 'eug'            male : female =      2.6 : 1.0
#                  prefix3 = 'fin'            male : female =      2.6 : 1.0
#                  prefix3 = 'gir'            male : female =      2.6 : 1.0
#                  prefix3 = 'iza'            male : female =      2.6 : 1.0
#                  prefix3 = 'lam'            male : female =      2.6 : 1.0
#                  prefix3 = 'mei'            male : female =      2.6 : 1.0
#                  prefix3 = 'moi'            male : female =      2.6 : 1.0
#                  prefix3 = 'nea'            male : female =      2.6 : 1.0
#                  prefix3 = 'odi'            male : female =      2.6 : 1.0
#                  prefix3 = 'ola'            male : female =      2.6 : 1.0
#                  prefix3 = 'ole'            male : female =      2.6 : 1.0
#                  prefix3 = 'oll'            male : female =      2.6 : 1.0
#                  prefix3 = 'ori'            male : female =      2.6 : 1.0
#                  prefix3 = 'pac'            male : female =      2.6 : 1.0
#                  prefix3 = 'pai'            male : female =      2.6 : 1.0
#                  prefix3 = 'rup'            male : female =      2.6 : 1.0
#                  prefix3 = 'sam'            male : female =      2.6 : 1.0
#                  prefix3 = 'sea'            male : female =      2.6 : 1.0
#                  prefix3 = 'sin'            male : female =      2.6 : 1.0
#                  prefix3 = 'sul'            male : female =      2.6 : 1.0
#                  prefix3 = 'zol'            male : female =      2.6 : 1.0
#                  suffix3 = 'aby'            male : female =      2.6 : 1.0
#                  suffix3 = 'ank'            male : female =      2.6 : 1.0
#                  suffix3 = 'ark'            male : female =      2.6 : 1.0
#                  suffix3 = 'arl'            male : female =      2.6 : 1.0
#                  suffix3 = 'cal'            male : female =      2.6 : 1.0
#                  suffix3 = 'dal'            male : female =      2.6 : 1.0
#                  suffix3 = 'eas'            male : female =      2.6 : 1.0
#                  suffix3 = 'eil'            male : female =      2.6 : 1.0
#                  suffix3 = 'elo'            male : female =      2.6 : 1.0
#                  suffix3 = 'emy'            male : female =      2.6 : 1.0
#                  suffix3 = 'ern'            male : female =      2.6 : 1.0
#                  suffix3 = 'fin'            male : female =      2.6 : 1.0
#                  suffix3 = 'gel'            male : female =      2.6 : 1.0
#                  suffix3 = 'had'            male : female =      2.6 : 1.0
#                  suffix3 = 'ili'            male : female =      2.6 : 1.0
#                  suffix3 = 'jay'            male : female =      2.6 : 1.0
#                  suffix3 = 'kel'            male : female =      2.6 : 1.0
#                  suffix3 = 'lex'            male : female =      2.6 : 1.0
#                  suffix3 = 'lio'            male : female =      2.6 : 1.0
#                  suffix3 = 'lix'            male : female =      2.6 : 1.0
#                  suffix3 = 'lor'            male : female =      2.6 : 1.0
#                  suffix3 = 'nen'            male : female =      2.6 : 1.0
#                  suffix3 = 'ois'            male : female =      2.6 : 1.0
#                  suffix3 = 'ray'            male : female =      2.6 : 1.0
#                  suffix3 = 'rdy'            male : female =      2.6 : 1.0
#                  suffix3 = 'rew'            male : female =      2.6 : 1.0
#                  suffix3 = 'rlo'            male : female =      2.6 : 1.0
#                  suffix3 = 'sly'            male : female =      2.6 : 1.0
#                  suffix3 = 'tes'            male : female =      2.6 : 1.0
#                  suffix3 = 'uri'            male : female =      2.6 : 1.0
#                  suffix3 = 'vor'            male : female =      2.6 : 1.0
#                  suffix3 = 'wyn'            male : female =      2.6 : 1.0
#                  suffix3 = 'zzy'            male : female =      2.6 : 1.0
#                  prefix2 = 'pi'             male : female =      2.6 : 1.0
#                  suffix2 = 'in'             male : female =      2.6 : 1.0
#                  prefix2 = 'iv'           female : male   =      2.6 : 1.0
#                  prefix2 = 'wi'             male : female =      2.6 : 1.0
#                  prefix2 = 'su'           female : male   =      2.5 : 1.0
#                  suffix2 = 'll'             male : female =      2.5 : 1.0
#                  suffix2 = 'de'           female : male   =      2.5 : 1.0
#                  prefix3 = 'jer'            male : female =      2.5 : 1.0
#                  prefix3 = 'dem'            male : female =      2.5 : 1.0
#                  prefix3 = 'ern'            male : female =      2.5 : 1.0
#                  suffix3 = 'dan'            male : female =      2.5 : 1.0
#                  suffix3 = 'rby'            male : female =      2.5 : 1.0
#                  suffix3 = 'tan'            male : female =      2.5 : 1.0
#                  prefix3 = 'cam'          female : male   =      2.5 : 1.0
#                  prefix2 = 'kr'           female : male   =      2.4 : 1.0
#                  prefix3 = 'mar'          female : male   =      2.4 : 1.0
#                  prefix2 = 'to'             male : female =      2.4 : 1.0
#                  prefix2 = 'wy'             male : female =      2.4 : 1.0
#                  prefix3 = 'reg'            male : female =      2.4 : 1.0
#                  prefix3 = 'joa'          female : male   =      2.4 : 1.0
#                  prefix3 = 'kir'          female : male   =      2.4 : 1.0
#                  suffix2 = 'at'             male : female =      2.4 : 1.0
#                  suffix3 = 'ael'            male : female =      2.4 : 1.0
#                  suffix3 = 'ten'            male : female =      2.4 : 1.0
#                  prefix3 = 'ant'            male : female =      2.4 : 1.0
#             first_letter = 'k'            female : male   =      2.4 : 1.0
#                  prefix2 = 'iz'             male : female =      2.4 : 1.0
#                  prefix2 = 'xe'             male : female =      2.4 : 1.0
#                  suffix2 = 'eg'             male : female =      2.3 : 1.0
#                  suffix2 = 'ei'             male : female =      2.3 : 1.0
#                  suffix2 = 'ou'             male : female =      2.3 : 1.0
#             first_letter = 'h'              male : female =      2.3 : 1.0
#                  suffix3 = 'acy'          female : male   =      2.3 : 1.0
#                  suffix3 = 'ste'          female : male   =      2.3 : 1.0
#                  suffix3 = 'ynn'          female : male   =      2.3 : 1.0
#                  prefix3 = 'bon'          female : male   =      2.3 : 1.0
#                  prefix3 = 'del'          female : male   =      2.3 : 1.0
#                  prefix3 = 'lot'          female : male   =      2.3 : 1.0
#                  prefix3 = 'mis'          female : male   =      2.3 : 1.0
#                  prefix3 = 'pri'          female : male   =      2.3 : 1.0
#                  prefix3 = 'til'          female : male   =      2.3 : 1.0
#                  prefix3 = 'zor'          female : male   =      2.3 : 1.0
#                  prefix3 = 'han'            male : female =      2.3 : 1.0
#                  suffix3 = 'ley'            male : female =      2.3 : 1.0
#                  suffix2 = 'gh'             male : female =      2.3 : 1.0
#                  suffix2 = 'ot'             male : female =      2.3 : 1.0
#                  prefix2 = 'ho'             male : female =      2.3 : 1.0
#                  prefix3 = 'sha'          female : male   =      2.3 : 1.0
#                  prefix3 = 'har'            male : female =      2.3 : 1.0
#                  prefix3 = 'ray'            male : female =      2.3 : 1.0
#                  prefix3 = 'wil'            male : female =      2.2 : 1.0
#                  prefix3 = 'mor'            male : female =      2.2 : 1.0
#                  suffix3 = 'lie'          female : male   =      2.2 : 1.0
#                  suffix2 = 'ky'             male : female =      2.2 : 1.0
#                  prefix3 = 'sal'            male : female =      2.2 : 1.0
#                  prefix3 = 'alb'            male : female =      2.2 : 1.0
#                  prefix3 = 'avr'            male : female =      2.2 : 1.0
#                  prefix3 = 'elw'            male : female =      2.2 : 1.0
#                  prefix3 = 'fri'            male : female =      2.2 : 1.0
#                  prefix3 = 'lio'            male : female =      2.2 : 1.0
#                  prefix3 = 'mit'            male : female =      2.2 : 1.0
#                  prefix3 = 'ora'            male : female =      2.2 : 1.0
#                  prefix3 = 'pep'            male : female =      2.2 : 1.0
#                  prefix3 = 'rey'            male : female =      2.2 : 1.0
#                  suffix2 = 've'             male : female =      2.2 : 1.0
#                  suffix3 = 'dge'            male : female =      2.2 : 1.0
#                  suffix3 = 'ish'            male : female =      2.2 : 1.0
#                  suffix3 = 'key'            male : female =      2.2 : 1.0
#                  suffix3 = 'ret'            male : female =      2.2 : 1.0
#                  suffix3 = 'rny'            male : female =      2.2 : 1.0
#                  suffix3 = 'say'            male : female =      2.2 : 1.0
#                  suffix2 = 'jo'           female : male   =      2.2 : 1.0
#                  prefix2 = 'ye'           female : male   =      2.2 : 1.0
#                  suffix3 = 'cha'          female : male   =      2.2 : 1.0
#                  prefix2 = 'lo'           female : male   =      2.2 : 1.0
#                  prefix3 = 'gin'          female : male   =      2.2 : 1.0
#                  prefix3 = 'noe'          female : male   =      2.2 : 1.0
#                  prefix3 = 'van'          female : male   =      2.2 : 1.0
#                  prefix2 = 'eb'             male : female =      2.2 : 1.0
#                  prefix2 = 'ga'             male : female =      2.2 : 1.0
#                  prefix2 = 'hi'             male : female =      2.2 : 1.0
#                  suffix2 = 'il'             male : female =      2.2 : 1.0
#                  suffix2 = 'ow'             male : female =      2.2 : 1.0
#                  suffix3 = 'ndy'          female : male   =      2.2 : 1.0
#                  prefix3 = 'tob'            male : female =      2.1 : 1.0
#                  prefix3 = 'tom'            male : female =      2.1 : 1.0
#                  prefix2 = 'me'           female : male   =      2.1 : 1.0
